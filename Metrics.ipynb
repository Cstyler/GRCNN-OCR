# %%
# %load_ext autoreload
# %autoreload 2

# %%
from grcnn import metrics
from grcnn.utils import find_best_model_epoch
# Out:
# Using TensorFlow backend.
# /home/agazade/.conda/envs/main/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/agazade/.conda/envs/main/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/agazade/.conda/envs/main/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/agazade/.conda/envs/main/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/agazade/.conda/envs/main/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/agazade/.conda/envs/main/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
dataset_dir_path = '/srv/data_science/storage/product_code_ocr'
max_text_len = 26
w, h = 100, 32
n_classes = 10

grcl_fsize = 3
# grcl_niter = 3
grcl_niter = 3
lstm_units = 512

# df_name = f'test_set_len{max_text_len}'
df_name = f'test_relabel_11_20_len{max_text_len}'
# df_name = f'val_set_len{max_text_len}'
# df_name = f'train_set_len{max_text_len}'
model_num = 51
epoch = find_best_model_epoch(model_num)
# epoch = 99 # m46
# epoch = 16 # m37
# epoch = 29 # m20
# epoch = 58 # m21
# epoch = 38 # m18

batch_size = 80
# image_dir = "images_train"
# image_dir = "images_train2"
# image_dir = "images_train3"
# image_dir = "images_train3"
# image_dir = f'cropped_images_train_size{w}x{h}' 
image_dir = f'images_train_padding_size{w}x{h}'
full_img_dir = 'processed_images'
dist_filter = lambda x: x > 0
debug = 1

# %%
sign(x-y)

# %%
metrics.test_nn(dataset_dir_path, df_name, model_num, epoch, batch_size, w, h, max_text_len,
                n_classes, grcl_niter, grcl_fsize, lstm_units,
                image_dir, full_img_dir, debug, dist_filter)
# Out:
# True text: 5449000000286 , Len: 13 , Pred text: 544900000028 , Dist: 1
# Pred argmax 55•4••44900•0•0•0•0••02888
# sym0. Pred [ 4 10  5] [0.015 0.384 0.485]
# sym1. Pred [ 4 10  5] [0.021 0.054 0.796]
# sym2. Pred [ 4  5 10] [0.313 0.314 0.314]
# sym3. Pred [ 5 10  4] [0.019 0.053 0.805]
# sym4. Pred [ 5  4 10] [0.009 0.448 0.473]
# sym5. Pred [ 9  4 10] [0.014 0.148 0.727]
# sym6. Pred [ 9 10  4] [0.012 0.435 0.463]
# sym7. Pred [ 9 10  4] [0.023 0.064 0.765]
# sym8. Pred [ 0 10  9] [0.039 0.107 0.599]
# sym9. Pred [ 9 10  0] [0.144 0.391 0.391]
# sym10. Pred [ 4 10  0] [0.015 0.053 0.809]
# sym11. Pred [ 4  0 10] [0.018 0.062 0.776]
# sym12. Pred [ 4 10  0] [0.018 0.062 0.776]
# sym13. Pred [ 4  0 10] [0.018 0.062 0.776]
# sym14. Pred [ 6 10  0] [0.018 0.062 0.776]
# sym15. Pred [ 1  0 10] [0.018 0.062 0.776]
# sym16. Pred [ 2 10  0] [0.018 0.062 0.776]
# sym17. Pred [ 2  0 10] [0.018 0.062 0.776]
# sym18. Pred [ 2 10  0] [0.018 0.062 0.775]
# sym19. Pred [ 2  0 10] [0.015 0.053 0.809]
# sym20. Pred [ 2  0 10] [0.011 0.444 0.46 ]
# sym21. Pred [ 2 10  0] [0.023 0.064 0.765]
# sym22. Pred [ 0 10  2] [0.039 0.107 0.598]
# sym23. Pred [10  2  8] [0.056 0.228 0.599]
# sym24. Pred [ 6 10  8] [0.023 0.063 0.761]
# sym25. Pred [10  6  8] [0.067 0.231 0.503]
# Tag id: f7c62633b3692dc6d1179f6c2866ea5b943a19ac
# True text: 895890 , Len: 6 , Pred text: 895850 , Dist: 2
# Pred argmax •••••8•••99••5••8••5••••0•
# sym0. Pred [ 0  8 10] [0.023 0.023 0.772]
# sym1. Pred [ 9  8 10] [0.016 0.017 0.835]
# sym2. Pred [ 4  8 10] [0.016 0.016 0.843]
# sym3. Pred [ 9  8 10] [0.016 0.02  0.837]
# sym4. Pred [ 9  8 10] [0.011 0.451 0.454]
# sym5. Pred [ 9 10  8] [0.016 0.055 0.803]
# sym6. Pred [ 9  8 10] [0.01  0.403 0.511]
# sym7. Pred [ 8  9 10] [0.02  0.022 0.831]
# sym8. Pred [ 8  9 10] [0.016 0.201 0.659]
# sym9. Pred [ 5 10  9] [0.034 0.134 0.592]
# sym10. Pred [ 5 10  9] [0.032 0.181 0.542]
# sym11. Pred [ 5  9 10] [0.02  0.065 0.795]
# sym12. Pred [ 8  5 10] [0.011 0.451 0.454]
# sym13. Pred [ 8 10  5] [0.016 0.055 0.803]
# sym14. Pred [ 8  5 10] [0.013 0.408 0.502]
# sym15. Pred [ 5  8 10] [0.014 0.45  0.452]
# sym16. Pred [ 5 10  8] [0.018 0.054 0.801]
# sym17. Pred [ 5  8 10] [0.018 0.405 0.498]
# sym18. Pred [ 9  5 10] [0.164 0.353 0.405]
# sym19. Pred [10  9  5] [0.045 0.218 0.631]
# sym20. Pred [ 9  5 10] [0.036 0.301 0.577]
# sym21. Pred [ 0  5 10] [0.016 0.02  0.84 ]
# sym22. Pred [ 5  0 10] [0.017 0.021 0.835]
# sym23. Pred [ 5  0 10] [0.011 0.451 0.454]
# sym24. Pred [ 5 10  0] [0.016 0.054 0.799]
# sym25. Pred [ 5  0 10] [0.013 0.44  0.442]
# Tag id: 46df09d20396d43581c165b4d156f6801f411f7f
# True text: 04607072710255 , Len: 14 , Pred text: 4607072710255 , Dist: 1
# Pred argmax •••4•6•0•770772771002•5••5
# sym0. Pred [ 4  0 10] [0.023 0.08  0.72 ]
# sym1. Pred [ 4  0 10] [0.025 0.134 0.683]
# sym2. Pred [ 0  4 10] [0.147 0.388 0.391]
# sym3. Pred [ 0 10  4] [0.02  0.054 0.796]
# sym4. Pred [ 4  6 10] [0.313 0.313 0.315]
# sym5. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym6. Pred [ 6  0 10] [0.313 0.313 0.315]
# sym7. Pred [ 7 10  0] [0.02  0.054 0.796]
# sym8. Pred [ 7  0 10] [0.313 0.313 0.315]
# sym9. Pred [ 0 10  7] [0.025 0.054 0.795]
# sym10. Pred [10  0  7] [0.037 0.433 0.447]
# sym11. Pred [10  7  0] [0.061 0.061 0.735]
# sym12. Pred [ 2 10  7] [0.02  0.054 0.796]
# sym13. Pred [ 2 10  7] [0.176 0.376 0.377]
# sym14. Pred [ 7 10  2] [0.05  0.106 0.597]
# sym15. Pred [10  2  7] [0.059 0.099 0.706]
# sym16. Pred [10  1  7] [0.051 0.22  0.611]
# sym17. Pred [ 0 10  1] [0.039 0.107 0.599]
# sym18. Pred [10  1  0] [0.047 0.274 0.568]
# sym19. Pred [ 2 10  0] [0.024 0.063 0.761]
# sym20. Pred [ 0 10  2] [0.039 0.106 0.598]
# sym21. Pred [ 2  5 10] [0.144 0.39  0.392]
# sym22. Pred [ 0 10  5] [0.016 0.055 0.803]
# sym23. Pred [ 0  5 10] [0.015 0.107 0.762]
# sym24. Pred [ 6  5 10] [0.011 0.442 0.458]
# sym25. Pred [ 6 10  5] [0.023 0.061 0.736]
# Tag id: 40ff7659b0fa527c504ecf9b0025797a2531d50d
# True text: 13600542115988 , Len: 14 , Pred text: 360054215988 , Dist: 2
# Pred argmax ••••3600••05542•11559•8••8
# sym0. Pred [ 6  1 10] [0.019 0.21  0.624]
# sym1. Pred [ 6  1 10] [0.013 0.245 0.636]
# sym2. Pred [ 6  1 10] [0.012 0.246 0.643]
# sym3. Pred [ 1  3 10] [0.033 0.193 0.564]
# sym4. Pred [ 6 10  3] [0.063 0.171 0.366]
# sym5. Pred [ 0 10  6] [0.024 0.064 0.764]
# sym6. Pred [ 6 10  0] [0.306 0.317 0.318]
# sym7. Pred [ 6 10  0] [0.019 0.053 0.805]
# sym8. Pred [ 6  0 10] [0.016 0.053 0.808]
# sym9. Pred [ 5  0 10] [0.011 0.444 0.46 ]
# sym10. Pred [10  5  0] [0.061 0.061 0.735]
# sym11. Pred [ 4 10  5] [0.02  0.054 0.796]
# sym12. Pred [ 4 10  5] [0.309 0.313 0.318]
# sym13. Pred [ 5 10  4] [0.023 0.063 0.762]
# sym14. Pred [ 4 10  2] [0.039 0.107 0.603]
# sym15. Pred [ 2  1 10] [0.191 0.191 0.52 ]
# sym16. Pred [ 5 10  1] [0.033 0.109 0.607]
# sym17. Pred [ 5 10  1] [0.047 0.104 0.605]
# sym18. Pred [10  1  5] [0.057 0.144 0.66 ]
# sym19. Pred [10  9  5] [0.049 0.259 0.576]
# sym20. Pred [ 5 10  9] [0.039 0.106 0.598]
# sym21. Pred [ 9  8 10] [0.144 0.39  0.392]
# sym22. Pred [ 5 10  8] [0.016 0.055 0.803]
# sym23. Pred [ 0  8 10] [0.015 0.106 0.763]
# sym24. Pred [ 4  8 10] [0.011 0.442 0.458]
# sym25. Pred [ 4 10  8] [0.023 0.061 0.736]
# Tag id: 25ce05f866c26089843267859bc1fbc934f64683
# True text: 3600540168481 , Len: 13 , Pred text: 360054016848 , Dist: 1
# Pred argmax •3•600••0•5•4•0•1•6•8•4•88
# sym0. Pred [ 6  3 10] [0.022 0.259 0.554]
# sym1. Pred [ 6 10  3] [0.064 0.169 0.361]
# sym2. Pred [ 3  6 10] [0.073 0.423 0.424]
# sym3. Pred [ 0 10  6] [0.02  0.054 0.8  ]
# sym4. Pred [ 6 10  0] [0.313 0.314 0.314]
# sym5. Pred [ 6 10  0] [0.019 0.053 0.805]
# sym6. Pred [ 6  0 10] [0.016 0.053 0.808]
# sym7. Pred [ 5  0 10] [0.011 0.451 0.453]
# sym8. Pred [ 5 10  0] [0.02  0.054 0.799]
# sym9. Pred [ 5  0 10] [0.313 0.313 0.315]
# sym10. Pred [ 0 10  5] [0.02  0.054 0.796]
# sym11. Pred [ 4  5 10] [0.313 0.313 0.315]
# sym12. Pred [ 0 10  4] [0.02  0.054 0.796]
# sym13. Pred [ 0  4 10] [0.313 0.313 0.315]
# sym14. Pred [ 4 10  0] [0.02  0.054 0.8  ]
# sym15. Pred [ 1  0 10] [0.144 0.39  0.392]
# sym16. Pred [ 6 10  1] [0.039 0.107 0.598]
# sym17. Pred [ 1  6 10] [0.175 0.376 0.378]
# sym18. Pred [ 8 10  6] [0.02  0.054 0.796]
# sym19. Pred [ 8  6 10] [0.313 0.313 0.315]
# sym20. Pred [ 6 10  8] [0.02  0.054 0.796]
# sym21. Pred [ 8  4 10] [0.313 0.313 0.315]
# sym22. Pred [ 8 10  4] [0.025 0.054 0.795]
# sym23. Pred [ 8  4 10] [0.309 0.315 0.316]
# sym24. Pred [ 1 10  8] [0.047 0.058 0.75 ]
# sym25. Pred [10  1  8] [0.156 0.285 0.409]
# Tag id: f1af0aec17686ca83003f2278cd3f217023980fc
# True text: 1337992 , Len: 7 , Pred text: 137992 , Dist: 1
# Pred argmax •1••••••3•••7••9•••9••••2•
# sym0. Pred [ 3  1 10] [0.021 0.259 0.554]
# sym1. Pred [ 3 10  1] [0.032 0.107 0.603]
# sym2. Pred [ 3  1 10] [0.016 0.24  0.648]
# sym3. Pred [ 1  3 10] [0.019 0.108 0.757]
# sym4. Pred [ 1  3 10] [0.02  0.14  0.688]
# sym5. Pred [ 1  3 10] [0.03  0.224 0.504]
# sym6. Pred [ 1  3 10] [0.014 0.107 0.763]
# sym7. Pred [ 7  3 10] [0.017 0.124 0.724]
# sym8. Pred [ 7 10  3] [0.051 0.174 0.372]
# sym9. Pred [ 7  3 10] [0.015 0.104 0.768]
# sym10. Pred [ 9  7 10] [0.016 0.02  0.837]
# sym11. Pred [ 9  7 10] [0.011 0.451 0.454]
# sym12. Pred [ 9 10  7] [0.016 0.055 0.803]
# sym13. Pred [ 9  7 10] [0.012 0.409 0.503]
# sym14. Pred [ 7  9 10] [0.018 0.277 0.595]
# sym15. Pred [ 7 10  9] [0.033 0.108 0.608]
# sym16. Pred [ 7  9 10] [0.013 0.2   0.686]
# sym17. Pred [ 7  9 10] [0.016 0.02  0.837]
# sym18. Pred [ 7  9 10] [0.014 0.278 0.597]
# sym19. Pred [ 2 10  9] [0.031 0.108 0.609]
# sym20. Pred [ 2  9 10] [0.013 0.199 0.687]
# sym21. Pred [ 0  2 10] [0.016 0.016 0.844]
# sym22. Pred [ 5  2 10] [0.016 0.02  0.837]
# sym23. Pred [ 0  2 10] [0.014 0.277 0.597]
# sym24. Pred [ 5 10  2] [0.032 0.107 0.603]
# sym25. Pred [ 5  2 10] [0.018 0.225 0.612]
# Tag id: 4426353f28109a902d9d7812af00f45aff73993b
# True text: 4601135600484 , Len: 13 , Pred text: 14601133600484 , Dist: 3
# Pred argmax •144•6001•13•3660••04•8•4•
# sym0. Pred [ 4  1 10] [0.022 0.256 0.556]
# sym1. Pred [ 4 10  1] [0.041 0.107 0.597]
# sym2. Pred [ 1 10  4] [0.175 0.377 0.377]
# sym3. Pred [ 6 10  4] [0.02  0.054 0.796]
# sym4. Pred [ 4  6 10] [0.313 0.313 0.315]
# sym5. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym6. Pred [10  6  0] [0.038 0.42  0.454]
# sym7. Pred [10  1  0] [0.061 0.062 0.729]
# sym8. Pred [ 0 10  1] [0.039 0.107 0.603]
# sym9. Pred [ 0  1 10] [0.019 0.05  0.785]
# sym10. Pred [ 0 10  1] [0.031 0.106 0.617]
# sym11. Pred [ 1 10  3] [0.063 0.172 0.367]
# sym12. Pred [ 6  3 10] [0.017 0.124 0.723]
# sym13. Pred [ 6 10  3] [0.063 0.171 0.367]
# sym14. Pred [10  3  6] [0.057 0.122 0.687]
# sym15. Pred [10  0  6] [0.056 0.134 0.679]
# sym16. Pred [ 6 10  0] [0.019 0.053 0.805]
# sym17. Pred [ 6  0 10] [0.016 0.053 0.808]
# sym18. Pred [ 4  0 10] [0.011 0.444 0.46 ]
# sym19. Pred [10  4  0] [0.061 0.061 0.735]
# sym20. Pred [ 8 10  4] [0.02  0.054 0.796]
# sym21. Pred [ 8  4 10] [0.313 0.313 0.315]
# sym22. Pred [ 4 10  8] [0.026 0.054 0.795]
# sym23. Pred [ 4  8 10] [0.312 0.313 0.315]
# sym24. Pred [ 8 10  4] [0.021 0.054 0.795]
# sym25. Pred [ 8  4 10] [0.014 0.44  0.442]
# Tag id: c933e9b611da73fd4b76958134cd4b2a521d1bc8
# True text: 8234607065001445 , Len: 16 , Pred text: 82460706500145 , Dist: 2
# Pred argmax 88•2•44•6607006500••01••45
# sym0. Pred [ 2 10  8] [0.015 0.386 0.484]
# sym1. Pred [ 2 10  8] [0.021 0.055 0.793]
# sym2. Pred [ 2  8 10] [0.193 0.315 0.414]
# sym3. Pred [ 8 10  2] [0.04  0.108 0.6  ]
# sym4. Pred [ 2  3 10] [0.113 0.138 0.589]
# sym5. Pred [10  3  4] [0.105 0.153 0.564]
# sym6. Pred [ 6 10  4] [0.02  0.054 0.799]
# sym7. Pred [ 4  6 10] [0.313 0.313 0.315]
# sym8. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym9. Pred [10  0  6] [0.038 0.433 0.445]
# sym10. Pred [10  7  0] [0.061 0.061 0.732]
# sym11. Pred [ 0 10  7] [0.025 0.054 0.795]
# sym12. Pred [10  7  0] [0.037 0.428 0.446]
# sym13. Pred [10  6  0] [0.057 0.122 0.684]
# sym14. Pred [ 0 10  6] [0.024 0.063 0.76 ]
# sym15. Pred [ 6 10  5] [0.028 0.063 0.757]
# sym16. Pred [10  5  0] [0.036 0.436 0.442]
# sym17. Pred [ 5 10  0] [0.019 0.053 0.805]
# sym18. Pred [ 5  0 10] [0.016 0.053 0.808]
# sym19. Pred [ 1  0 10] [0.013 0.443 0.459]
# sym20. Pred [10  1  0] [0.059 0.095 0.704]
# sym21. Pred [10  4  1] [0.091 0.183 0.508]
# sym22. Pred [ 1  4 10] [0.028 0.13  0.73 ]
# sym23. Pred [ 1  4 10] [0.012 0.438 0.463]
# sym24. Pred [10  5  4] [0.058 0.116 0.687]
# sym25. Pred [ 4 10  5] [0.03  0.062 0.724]
# Tag id: 33410f91f63cba5178456a122ad2c425c01e0cd0
# True text: 4610014319388 , Len: 13 , Pred text: 4610014319386 , Dist: 2
# Pred argmax 4446•1•0••0•14•3•1•9•3•8•6
# sym0. Pred [ 6 10  4] [0.015 0.384 0.485]
# sym1. Pred [ 6 10  4] [0.021 0.054 0.796]
# sym2. Pred [10  6  4] [0.314 0.314 0.314]
# sym3. Pred [ 4 10  6] [0.02  0.054 0.8  ]
# sym4. Pred [ 1  6 10] [0.144 0.39  0.392]
# sym5. Pred [ 0 10  1] [0.039 0.107 0.599]
# sym6. Pred [ 1  0 10] [0.175 0.377 0.377]
# sym7. Pred [ 1 10  0] [0.019 0.053 0.805]
# sym8. Pred [ 1  0 10] [0.016 0.053 0.808]
# sym9. Pred [ 1  0 10] [0.011 0.451 0.454]
# sym10. Pred [ 4 10  0] [0.016 0.055 0.803]
# sym11. Pred [ 1  0 10] [0.144 0.39  0.392]
# sym12. Pred [ 0 10  1] [0.039 0.107 0.599]
# sym13. Pred [ 1 10  4] [0.023 0.064 0.765]
# sym14. Pred [ 3  4 10] [0.074 0.415 0.43 ]
# sym15. Pred [ 4 10  3] [0.063 0.171 0.367]
# sym16. Pred [ 3  1 10] [0.099 0.213 0.579]
# sym17. Pred [ 9 10  1] [0.04  0.107 0.604]
# sym18. Pred [ 9  1 10] [0.22  0.22  0.473]
# sym19. Pred [ 1 10  9] [0.04  0.107 0.604]
# sym20. Pred [ 3  9 10] [0.099 0.213 0.579]
# sym21. Pred [ 8 10  3] [0.063 0.171 0.367]
# sym22. Pred [ 3  8 10] [0.073 0.423 0.425]
# sym23. Pred [ 6 10  8] [0.02  0.054 0.799]
# sym24. Pred [ 6  8 10] [0.306 0.316 0.317]
# sym25. Pred [ 8 10  6] [0.028 0.061 0.732]
# Tag id: e8509c54cd511e26b529a5149669b6d9e7bfd16e
# True text: 4607005520241 , Len: 13 , Pred text: 14607005520241 , Dist: 1
# Pred argmax •144•6607•0•05••52•02•4•1•
# sym0. Pred [ 4  1 10] [0.023 0.211 0.589]
# sym1. Pred [ 4 10  1] [0.041 0.113 0.587]
# sym2. Pred [ 1 10  4] [0.168 0.38  0.38 ]
# sym3. Pred [ 6 10  4] [0.02  0.054 0.796]
# sym4. Pred [ 4  6 10] [0.313 0.313 0.315]
# sym5. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym6. Pred [10  0  6] [0.037 0.433 0.446]
# sym7. Pred [10  7  0] [0.061 0.061 0.732]
# sym8. Pred [ 0 10  7] [0.025 0.054 0.795]
# sym9. Pred [ 7  0 10] [0.313 0.314 0.314]
# sym10. Pred [ 7 10  0] [0.019 0.053 0.805]
# sym11. Pred [ 5  0 10] [0.019 0.062 0.774]
# sym12. Pred [ 5 10  0] [0.027 0.074 0.727]
# sym13. Pred [ 0 10  5] [0.024 0.064 0.764]
# sym14. Pred [ 0  5 10] [0.015 0.104 0.765]
# sym15. Pred [ 2  5 10] [0.011 0.443 0.46 ]
# sym16. Pred [ 2 10  5] [0.023 0.064 0.765]
# sym17. Pred [ 0 10  2] [0.039 0.107 0.599]
# sym18. Pred [ 2  0 10] [0.146 0.383 0.397]
# sym19. Pred [ 2 10  0] [0.023 0.064 0.764]
# sym20. Pred [ 0 10  2] [0.052 0.105 0.59 ]
# sym21. Pred [ 2  4 10] [0.194 0.287 0.419]
# sym22. Pred [ 6 10  4] [0.017 0.054 0.801]
# sym23. Pred [ 1  4 10] [0.144 0.39  0.392]
# sym24. Pred [ 4 10  1] [0.041 0.106 0.597]
# sym25. Pred [ 4  1 10] [0.018 0.268 0.578]
# Tag id: 403ff8c3a36d2c27a7a03e5859008c03590f7f13
# True text: 84607025966975 , Len: 14 , Pred text: 4607025966975 , Dist: 1
# Pred argmax •••4•6•0•7702559•6••69•7•5
# sym0. Pred [ 4  8 10] [0.023 0.036 0.76 ]
# sym1. Pred [ 4  8 10] [0.021 0.055 0.794]
# sym2. Pred [ 8  4 10] [0.051 0.433 0.433]
# sym3. Pred [ 6 10  4] [0.02  0.054 0.797]
# sym4. Pred [ 4  6 10] [0.313 0.313 0.315]
# sym5. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym6. Pred [ 6  0 10] [0.313 0.313 0.315]
# sym7. Pred [ 7 10  0] [0.02  0.054 0.796]
# sym8. Pred [ 7  0 10] [0.313 0.313 0.315]
# sym9. Pred [ 0 10  7] [0.025 0.054 0.795]
# sym10. Pred [10  0  7] [0.269 0.328 0.338]
# sym11. Pred [ 2 10  0] [0.031 0.063 0.755]
# sym12. Pred [ 5 10  2] [0.039 0.106 0.598]
# sym13. Pred [ 2 10  5] [0.151 0.375 0.396]
# sym14. Pred [ 9 10  5] [0.023 0.064 0.765]
# sym15. Pred [ 6 10  9] [0.039 0.107 0.599]
# sym16. Pred [ 9  6 10] [0.144 0.39  0.392]
# sym17. Pred [ 5 10  6] [0.016 0.055 0.802]
# sym18. Pred [ 9  6 10] [0.015 0.103 0.766]
# sym19. Pred [ 9  6 10] [0.013 0.443 0.459]
# sym20. Pred [ 9 10  6] [0.023 0.064 0.765]
# sym21. Pred [ 6 10  9] [0.039 0.107 0.599]
# sym22. Pred [ 9  7 10] [0.144 0.39  0.392]
# sym23. Pred [ 5 10  7] [0.02  0.054 0.799]
# sym24. Pred [ 5  7 10] [0.306 0.316 0.317]
# sym25. Pred [ 7 10  5] [0.028 0.061 0.732]
# Tag id: 5540d9fa940f17009b9174ee26381f99f64fc4c8
# True text: 74602486003306 , Len: 14 , Pred text: 4602486003306 , Dist: 1
# Pred argmax •••4•6•02448•6•0•03••30•6•
# sym0. Pred [ 4  7 10] [0.021 0.13  0.685]
# sym1. Pred [ 4  7 10] [0.022 0.193 0.656]
# sym2. Pred [ 7  4 10] [0.161 0.383 0.383]
# sym3. Pred [ 6 10  4] [0.02  0.054 0.796]
# sym4. Pred [ 4  6 10] [0.313 0.313 0.315]
# sym5. Pred [ 4 10  6] [0.02  0.054 0.796]
# sym6. Pred [ 0  6 10] [0.307 0.316 0.318]
# sym7. Pred [ 6 10  0] [0.023 0.063 0.761]
# sym8. Pred [ 4 10  2] [0.039 0.106 0.597]
# sym9. Pred [10  2  4] [0.05  0.23  0.603]
# sym10. Pred [10  8  4] [0.057 0.123 0.687]
# sym11. Pred [ 6 10  8] [0.02  0.054 0.796]
# sym12. Pred [ 6  8 10] [0.313 0.313 0.315]
# sym13. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym14. Pred [ 6  0 10] [0.313 0.314 0.314]
# sym15. Pred [ 6 10  0] [0.019 0.053 0.805]
# sym16. Pred [ 6  0 10] [0.019 0.062 0.775]
# sym17. Pred [ 6 10  0] [0.022 0.074 0.731]
# sym18. Pred [ 0 10  3] [0.063 0.172 0.367]
# sym19. Pred [ 0  3 10] [0.015 0.107 0.762]
# sym20. Pred [ 0  3 10] [0.018 0.124 0.724]
# sym21. Pred [ 0 10  3] [0.063 0.171 0.367]
# sym22. Pred [10  3  0] [0.074 0.117 0.631]
# sym23. Pred [ 0  6 10] [0.283 0.286 0.363]
# sym24. Pred [ 0 10  6] [0.036 0.053 0.783]
# sym25. Pred [ 0  6 10] [0.015 0.439 0.441]
# Tag id: 7932a06ef5ba6ca7f5de3a487e9751255e4dab49
# True text: 17622210770660 , Len: 14 , Pred text: 7622210770660 , Dist: 1
# Pred argmax ••77•62•2•2•107•7•0•6•6•0•
# sym0. Pred [ 7  1 10] [0.022 0.142 0.67 ]
# sym1. Pred [ 7  1 10] [0.021 0.304 0.544]
# sym2. Pred [ 1 10  7] [0.179 0.368 0.382]
# sym3. Pred [ 6 10  7] [0.02  0.054 0.796]
# sym4. Pred [ 6  7 10] [0.307 0.316 0.318]
# sym5. Pred [ 2 10  6] [0.023 0.063 0.762]
# sym6. Pred [ 6 10  2] [0.04  0.108 0.602]
# sym7. Pred [ 6  2 10] [0.018 0.098 0.746]
# sym8. Pred [ 6 10  2] [0.032 0.108 0.608]
# sym9. Pred [ 0  2 10] [0.017 0.1   0.744]
# sym10. Pred [ 0 10  2] [0.032 0.108 0.609]
# sym11. Pred [ 1  2 10] [0.191 0.191 0.52 ]
# sym12. Pred [ 0 10  1] [0.04  0.107 0.603]
# sym13. Pred [10  7  0] [0.07  0.07  0.691]
# sym14. Pred [ 0 10  7] [0.024 0.064 0.764]
# sym15. Pred [ 0  7 10] [0.019 0.062 0.774]
# sym16. Pred [ 0 10  7] [0.02  0.054 0.8  ]
# sym17. Pred [ 0  7 10] [0.313 0.313 0.315]
# sym18. Pred [ 6 10  0] [0.02  0.054 0.796]
# sym19. Pred [ 6  0 10] [0.313 0.313 0.315]
# sym20. Pred [ 0 10  6] [0.02  0.054 0.799]
# sym21. Pred [ 0  6 10] [0.018 0.123 0.724]
# sym22. Pred [ 0 10  6] [0.023 0.065 0.764]
# sym23. Pred [ 0  6 10] [0.087 0.411 0.423]
# sym24. Pred [ 6 10  0] [0.021 0.054 0.795]
# sym25. Pred [ 6  0 10] [0.014 0.44  0.442]
# Tag id: 5547fd943d049c0bb3c2deaa1e1f7e3db118dca4
# True text: 4770190063333 , Len: 13 , Pred text: 477019006333 , Dist: 1
# Pred argmax 44•7••7•0•19•0••063••33••3
# sym0. Pred [ 7 10  4] [0.015 0.384 0.485]
# sym1. Pred [ 7 10  4] [0.021 0.054 0.796]
# sym2. Pred [ 7  4 10] [0.314 0.314 0.314]
# sym3. Pred [ 4 10  7] [0.02  0.054 0.799]
# sym4. Pred [ 4  7 10] [0.013 0.23  0.657]
# sym5. Pred [ 0  7 10] [0.011 0.451 0.454]
# sym6. Pred [ 0 10  7] [0.02  0.054 0.8  ]
# sym7. Pred [ 7  0 10] [0.313 0.313 0.315]
# sym8. Pred [ 7 10  0] [0.02  0.054 0.8  ]
# sym9. Pred [ 1  0 10] [0.144 0.39  0.392]
# sym10. Pred [ 0 10  1] [0.041 0.106 0.598]
# sym11. Pred [ 0 10  9] [0.041 0.106 0.598]
# sym12. Pred [ 9  0 10] [0.144 0.391 0.391]
# sym13. Pred [ 1 10  0] [0.015 0.053 0.809]
# sym14. Pred [ 6  0 10] [0.015 0.053 0.809]
# sym15. Pred [ 6  0 10] [0.011 0.444 0.46 ]
# sym16. Pred [10  6  0] [0.057 0.122 0.688]
# sym17. Pred [ 0 10  6] [0.023 0.064 0.765]
# sym18. Pred [ 6 10  3] [0.063 0.171 0.367]
# sym19. Pred [ 6  3 10] [0.015 0.107 0.762]
# sym20. Pred [ 6  3 10] [0.017 0.124 0.724]
# sym21. Pred [ 7 10  3] [0.048 0.216 0.353]
# sym22. Pred [ 6 10  3] [0.05  0.174 0.372]
# sym23. Pred [ 4  3 10] [0.015 0.107 0.762]
# sym24. Pred [ 5  3 10] [0.017 0.124 0.72 ]
# sym25. Pred [ 6 10  3] [0.057 0.155 0.332]
# Tag id: 55968e39faad0e2a1ce3c95998cc647453ec79b7
# True text: 774539 , Len: 6 , Pred text: 774639 , Dist: 2
# Pred argmax 77••••7•••4•••6••3••••••9•
# sym0. Pred [ 1 10  7] [0.014 0.385 0.486]
# sym1. Pred [ 1 10  7] [0.016 0.054 0.799]
# sym2. Pred [ 5  7 10] [0.009 0.403 0.512]
# sym3. Pred [ 4  7 10] [0.015 0.02  0.84 ]
# sym4. Pred [ 4  7 10] [0.016 0.021 0.836]
# sym5. Pred [ 4  7 10] [0.011 0.451 0.454]
# sym6. Pred [ 4 10  7] [0.016 0.055 0.803]
# sym7. Pred [ 4  7 10] [0.01  0.403 0.512]
# sym8. Pred [ 4  7 10] [0.02  0.02  0.833]
# sym9. Pred [ 7  4 10] [0.011 0.451 0.453]
# sym10. Pred [ 6 10  4] [0.016 0.055 0.803]
# sym11. Pred [ 6  4 10] [0.01  0.403 0.512]
# sym12. Pred [ 4  6 10] [0.02  0.02  0.833]
# sym13. Pred [ 4  6 10] [0.011 0.451 0.453]
# sym14. Pred [ 4 10  6] [0.016 0.055 0.803]
# sym15. Pred [ 4  6 10] [0.01  0.41  0.504]
# sym16. Pred [ 6  3 10] [0.021 0.124 0.721]
# sym17. Pred [ 6 10  3] [0.052 0.174 0.372]
# sym18. Pred [ 6  3 10] [0.014 0.104 0.769]
# sym19. Pred [ 6  9 10] [0.015 0.015 0.845]
# sym20. Pred [ 6  9 10] [0.015 0.016 0.845]
# sym21. Pred [ 6  9 10] [0.016 0.016 0.844]
# sym22. Pred [ 2  9 10] [0.016 0.02  0.837]
# sym23. Pred [ 2  9 10] [0.014 0.277 0.597]
# sym24. Pred [ 0 10  9] [0.032 0.107 0.603]
# sym25. Pred [ 6  9 10] [0.018 0.225 0.612]
# Tag id: e09ecb29ec27144a34dd1ae18a789d07ddd4dfed
# True text: 4620001321810 , Len: 13 , Pred text: 4620001324810 , Dist: 2
# Pred argmax 4446•200•0••01•3•2•4•8•1•0
# sym0. Pred [ 6 10  4] [0.015 0.384 0.485]
# sym1. Pred [ 6 10  4] [0.021 0.054 0.795]
# sym2. Pred [10  6  4] [0.314 0.314 0.314]
# sym3. Pred [ 2 10  6] [0.02  0.054 0.796]
# sym4. Pred [ 2  6 10] [0.176 0.376 0.378]
# sym5. Pred [ 0 10  2] [0.039 0.107 0.599]
# sym6. Pred [ 2  0 10] [0.144 0.391 0.391]
# sym7. Pred [ 6 10  0] [0.015 0.053 0.809]
# sym8. Pred [ 6  0 10] [0.018 0.062 0.776]
# sym9. Pred [ 6 10  0] [0.018 0.062 0.775]
# sym10. Pred [ 6  0 10] [0.015 0.053 0.809]
# sym11. Pred [ 2  0 10] [0.011 0.444 0.46 ]
# sym12. Pred [ 1 10  0] [0.049 0.062 0.745]
# sym13. Pred [ 0 10  1] [0.04  0.107 0.604]
# sym14. Pred [ 3  1 10] [0.094 0.255 0.548]
# sym15. Pred [ 2 10  3] [0.062 0.169 0.362]
# sym16. Pred [ 3  2 10] [0.094 0.255 0.548]
# sym17. Pred [ 4 10  2] [0.04  0.107 0.603]
# sym18. Pred [ 2  4 10] [0.142 0.384 0.387]
# sym19. Pred [ 1 10  4] [0.021 0.056 0.788]
# sym20. Pred [ 4  8 10] [0.297 0.309 0.31 ]
# sym21. Pred [ 4 10  8] [0.021 0.054 0.796]
# sym22. Pred [ 1  8 10] [0.144 0.39  0.392]
# sym23. Pred [ 8 10  1] [0.039 0.106 0.598]
# sym24. Pred [ 1  0 10] [0.177 0.368 0.381]
# sym25. Pred [ 1 10  0] [0.028 0.061 0.732]
# Tag id: 7d0b06fa219f43940f23641610465520cf1622bd
# True text: 64003301044267 , Len: 14 , Pred text: 64003301044262 , Dist: 2
# Pred argmax 66•400••03•3001044•442662•
# sym0. Pred [ 4 10  6] [0.015 0.384 0.485]
# sym1. Pred [ 4 10  6] [0.021 0.054 0.795]
# sym2. Pred [ 4  6 10] [0.312 0.315 0.315]
# sym3. Pred [ 0 10  4] [0.02  0.054 0.796]
# sym4. Pred [ 4 10  0] [0.313 0.314 0.314]
# sym5. Pred [ 4 10  0] [0.019 0.053 0.805]
# sym6. Pred [ 4  0 10] [0.016 0.053 0.808]
# sym7. Pred [ 4  0 10] [0.011 0.444 0.46 ]
# sym8. Pred [ 4 10  0] [0.019 0.064 0.769]
# sym9. Pred [ 0 10  3] [0.063 0.172 0.367]
# sym10. Pred [ 0  3 10] [0.018 0.124 0.723]
# sym11. Pred [ 0 10  3] [0.063 0.172 0.367]
# sym12. Pred [10  3  0] [0.057 0.122 0.688]
# sym13. Pred [10  1  0] [0.051 0.216 0.615]
# sym14. Pred [ 0 10  1] [0.05  0.106 0.597]
# sym15. Pred [ 4 10  0] [0.023 0.063 0.762]
# sym16. Pred [10  0  4] [0.296 0.317 0.325]
# sym17. Pred [ 0 10  4] [0.021 0.057 0.791]
# sym18. Pred [ 2  4 10] [0.017 0.089 0.766]
# sym19. Pred [ 2 10  4] [0.019 0.267 0.591]
# sym20. Pred [10  2  4] [0.049 0.283 0.55 ]
# sym21. Pred [ 6 10  2] [0.075 0.105 0.563]
# sym22. Pred [10  2  6] [0.059 0.116 0.689]
# sym23. Pred [ 7 10  6] [0.035 0.074 0.732]
# sym24. Pred [ 6 10  2] [0.04  0.106 0.596]
# sym25. Pred [ 6  2 10] [0.019 0.225 0.612]
# Tag id: 87135bc68016353a13d0b9618c7e976eac1e718c
# True text: 09000101075113 , Len: 14 , Pred text: 07900010107513 , Dist: 2
# Pred argmax 00•7900•0••010010775•1•33•
# sym0. Pred [ 7 10  0] [0.016 0.404 0.458]
# sym1. Pred [ 7 10  0] [0.025 0.054 0.79 ]
# sym2. Pred [ 7  0 10] [0.242 0.335 0.353]
# sym3. Pred [ 9 10  7] [0.064 0.078 0.667]
# sym4. Pred [ 7 10  9] [0.041 0.106 0.597]
# sym5. Pred [ 9 10  0] [0.144 0.391 0.391]
# sym6. Pred [ 7 10  0] [0.015 0.053 0.809]
# sym7. Pred [ 7  0 10] [0.018 0.062 0.776]
# sym8. Pred [ 7 10  0] [0.018 0.062 0.775]
# sym9. Pred [ 7  0 10] [0.015 0.053 0.809]
# sym10. Pred [ 7  0 10] [0.011 0.444 0.46 ]
# sym11. Pred [ 1 10  0] [0.049 0.062 0.745]
# sym12. Pred [ 0 10  1] [0.05  0.106 0.597]
# sym13. Pred [ 1 10  0] [0.023 0.064 0.765]
# sym14. Pred [10  1  0] [0.176 0.2   0.523]
# sym15. Pred [ 0 10  1] [0.05  0.106 0.596]
# sym16. Pred [10  7  0] [0.066 0.066 0.708]
# sym17. Pred [10  0  7] [0.049 0.108 0.724]
# sym18. Pred [10  5  7] [0.054 0.164 0.655]
# sym19. Pred [ 7 10  5] [0.02  0.054 0.797]
# sym20. Pred [ 1  5 10] [0.144 0.39  0.392]
# sym21. Pred [ 5 10  1] [0.04  0.107 0.604]
# sym22. Pred [ 3  1 10] [0.014 0.277 0.597]
# sym23. Pred [ 1 10  3] [0.063 0.179 0.363]
# sym24. Pred [ 1 10  3] [0.053 0.171 0.366]
# sym25. Pred [ 1  3 10] [0.021 0.119 0.696]
# Tag id: 7aad65850bc360fc7a70d63d750f71b873883735
# True text: 3600523473366 , Len: 13 , Pred text: 3800523473366 , Dist: 2
# Pred argmax •3•8•0••05223•4•7•3•3•6••6
# sym0. Pred [ 8  3 10] [0.022 0.257 0.555]
# sym1. Pred [ 8 10  3] [0.064 0.166 0.356]
# sym2. Pred [ 3  8 10] [0.107 0.145 0.622]
# sym3. Pred [10  6  8] [0.072 0.107 0.648]
# sym4. Pred [ 8  0 10] [0.152 0.385 0.385]
# sym5. Pred [ 8 10  0] [0.019 0.053 0.805]
# sym6. Pred [ 8  0 10] [0.016 0.053 0.808]
# sym7. Pred [ 5  0 10] [0.011 0.444 0.46 ]
# sym8. Pred [10  5  0] [0.061 0.061 0.735]
# sym9. Pred [ 2 10  5] [0.023 0.063 0.764]
# sym10. Pred [10  5  2] [0.098 0.165 0.52 ]
# sym11. Pred [10  3  2] [0.1   0.211 0.452]
# sym12. Pred [ 4 10  3] [0.063 0.171 0.367]
# sym13. Pred [ 3  4 10] [0.073 0.423 0.425]
# sym14. Pred [ 7 10  4] [0.02  0.054 0.8  ]
# sym15. Pred [ 7  4 10] [0.313 0.313 0.315]
# sym16. Pred [ 4 10  7] [0.02  0.054 0.8  ]
# sym17. Pred [ 3  7 10] [0.074 0.418 0.429]
# sym18. Pred [ 7 10  3] [0.063 0.171 0.367]
# sym19. Pred [ 7  3 10] [0.017 0.124 0.723]
# sym20. Pred [ 6 10  3] [0.063 0.172 0.367]
# sym21. Pred [ 3  6 10] [0.073 0.423 0.425]
# sym22. Pred [ 7 10  6] [0.016 0.055 0.802]
# sym23. Pred [ 8  6 10] [0.015 0.103 0.766]
# sym24. Pred [ 8  6 10] [0.011 0.442 0.458]
# sym25. Pred [ 7 10  6] [0.023 0.061 0.736]
# Tag id: 3a87c7161591d2555a812cf7be4c68c06358e1b2
# True text: 14600494602023 , Len: 14 , Pred text: 4600494602023 , Dist: 1
# Pred argmax •••4•6•0••049•4660•2•0•2•3
# sym0. Pred [ 7  4 10] [0.023 0.024 0.771]
# sym1. Pred [ 6  4 10] [0.017 0.021 0.827]
# sym2. Pred [ 1  4 10] [0.011 0.452 0.452]
# sym3. Pred [ 6 10  4] [0.02  0.054 0.8  ]
# sym4. Pred [ 6  4 10] [0.313 0.313 0.315]
# sym5. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym6. Pred [ 6  0 10] [0.313 0.314 0.314]
# sym7. Pred [ 6 10  0] [0.019 0.053 0.805]
# sym8. Pred [ 6  0 10] [0.016 0.053 0.808]
# sym9. Pred [ 4  0 10] [0.011 0.444 0.46 ]
# sym10. Pred [10  4  0] [0.061 0.061 0.735]
# sym11. Pred [ 0 10  4] [0.023 0.063 0.762]
# sym12. Pred [ 4 10  9] [0.05  0.106 0.597]
# sym13. Pred [ 9  4 10] [0.147 0.389 0.39 ]
# sym14. Pred [ 6 10  4] [0.022 0.06  0.78 ]
# sym15. Pred [10  4  6] [0.058 0.1   0.702]
# sym16. Pred [ 0 10  6] [0.121 0.202 0.564]
# sym17. Pred [ 6 10  0] [0.02  0.054 0.796]
# sym18. Pred [ 2  0 10] [0.176 0.376 0.378]
# sym19. Pred [ 0 10  2] [0.05  0.106 0.597]
# sym20. Pred [ 2  0 10] [0.144 0.39  0.392]
# sym21. Pred [ 2 10  0] [0.02  0.054 0.8  ]
# sym22. Pred [ 2  0 10] [0.176 0.376 0.378]
# sym23. Pred [ 0 10  2] [0.04  0.107 0.603]
# sym24. Pred [ 3  2 10] [0.099 0.212 0.577]
# sym25. Pred [ 0 10  3] [0.057 0.155 0.332]
# Tag id: 88832367d3fc7b96a8b6af9919de917512f7f46e
# True text: 37622210451255 , Len: 14 , Pred text: 7622210451255 , Dist: 1
# Pred argmax ••77•62•2••2•10445•12•5••5
# sym0. Pred [ 1  3 10] [0.075 0.187 0.592]
# sym1. Pred [ 1  3 10] [0.026 0.128 0.697]
# sym2. Pred [ 3 10  7] [0.073 0.423 0.423]
# sym3. Pred [ 6 10  7] [0.02  0.054 0.799]
# sym4. Pred [ 6  7 10] [0.307 0.316 0.318]
# sym5. Pred [ 2 10  6] [0.024 0.063 0.761]
# sym6. Pred [ 6 10  2] [0.04  0.108 0.602]
# sym7. Pred [ 6  2 10] [0.018 0.099 0.744]
# sym8. Pred [ 6 10  2] [0.031 0.106 0.617]
# sym9. Pred [ 6  2 10] [0.014 0.107 0.763]
# sym10. Pred [ 0  2 10] [0.014 0.278 0.597]
# sym11. Pred [ 0 10  2] [0.032 0.108 0.609]
# sym12. Pred [ 1  2 10] [0.191 0.191 0.52 ]
# sym13. Pred [ 0 10  1] [0.039 0.107 0.603]
# sym14. Pred [10  4  0] [0.061 0.061 0.731]
# sym15. Pred [10  0  4] [0.053 0.113 0.708]
# sym16. Pred [10  5  4] [0.057 0.111 0.697]
# sym17. Pred [ 4 10  5] [0.02  0.054 0.799]
# sym18. Pred [ 1  5 10] [0.144 0.39  0.392]
# sym19. Pred [ 5 10  1] [0.041 0.106 0.598]
# sym20. Pred [ 5 10  2] [0.041 0.106 0.598]
# sym21. Pred [ 2  5 10] [0.144 0.39  0.392]
# sym22. Pred [ 1 10  5] [0.016 0.055 0.802]
# sym23. Pred [ 1  5 10] [0.015 0.105 0.764]
# sym24. Pred [ 1  5 10] [0.011 0.441 0.46 ]
# sym25. Pred [ 1 10  5] [0.023 0.061 0.736]
# Tag id: b1a9d9132618495706b5c300225bc1a58057692e
# True text: 208589 , Len: 6 , Pred text: 2080 , Dist: 4
# Pred argmax •2••088••0••••••••••••••••
# sym0. Pred [ 0  2 10] [0.02  0.306 0.519]
# sym1. Pred [ 0 10  2] [0.041 0.106 0.597]
# sym2. Pred [ 0  2 10] [0.04  0.2   0.659]
# sym3. Pred [ 8  0 10] [0.013 0.444 0.456]
# sym4. Pred [ 8 10  0] [0.037 0.174 0.656]
# sym5. Pred [ 0 10  8] [0.109 0.216 0.466]
# sym6. Pred [ 6 10  8] [0.04  0.072 0.71 ]
# sym7. Pred [ 5  3 10] [0.137 0.153 0.298]
# sym8. Pred [ 0  3 10] [0.126 0.196 0.294]
# sym9. Pred [ 8 10  0] [0.019 0.192 0.653]
# sym10. Pred [ 8  0 10] [0.01  0.376 0.535]
# sym11. Pred [ 7  0 10] [0.016 0.023 0.838]
# sym12. Pred [ 7  0 10] [0.017 0.018 0.842]
# sym13. Pred [ 8  0 10] [0.015 0.016 0.845]
# sym14. Pred [ 8  0 10] [0.015 0.016 0.845]
# sym15. Pred [ 8  0 10] [0.015 0.015 0.845]
# sym16. Pred [ 9  0 10] [0.015 0.015 0.845]
# sym17. Pred [ 9  0 10] [0.015 0.015 0.845]
# sym18. Pred [ 9  0 10] [0.015 0.015 0.845]
# sym19. Pred [ 9  0 10] [0.015 0.015 0.845]
# sym20. Pred [ 9  0 10] [0.015 0.015 0.845]
# sym21. Pred [ 9  5 10] [0.015 0.015 0.845]
# sym22. Pred [ 9  5 10] [0.015 0.015 0.845]
# sym23. Pred [ 0  5 10] [0.016 0.016 0.844]
# sym24. Pred [ 0  5 10] [0.016 0.016 0.836]
# sym25. Pred [ 0  5 10] [0.023 0.023 0.772]
# Tag id: d76a5b0bce57318eb6faab012e89d89217cb91bf
# True text: 324607065606619 , Len: 15 , Pred text: 24607065606619 , Dist: 1
# Pred argmax ••2•4•6•007006556606••619•
# sym0. Pred [ 3  2 10] [0.024 0.03  0.76 ]
# sym1. Pred [ 3  2 10] [0.034 0.129 0.697]
# sym2. Pred [ 4 10  2] [0.024 0.064 0.764]
# sym3. Pred [ 2  4 10] [0.114 0.404 0.406]
# sym4. Pred [ 6 10  4] [0.02  0.054 0.799]
# sym5. Pred [ 4  6 10] [0.313 0.313 0.315]
# sym6. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym7. Pred [ 6  0 10] [0.313 0.313 0.315]
# sym8. Pred [ 7 10  0] [0.02  0.054 0.796]
# sym9. Pred [ 7 10  0] [0.312 0.313 0.315]
# sym10. Pred [ 0 10  7] [0.026 0.057 0.785]
# sym11. Pred [10  7  0] [0.057 0.113 0.691]
# sym12. Pred [10  6  0] [0.041 0.371 0.493]
# sym13. Pred [ 0 10  6] [0.023 0.064 0.761]
# sym14. Pred [ 6 10  5] [0.03  0.063 0.76 ]
# sym15. Pred [10  6  5] [0.13  0.395 0.398]
# sym16. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym17. Pred [10  0  6] [0.036 0.435 0.444]
# sym18. Pred [10  6  0] [0.057 0.12  0.69 ]
# sym19. Pred [ 0 10  6] [0.02  0.055 0.798]
# sym20. Pred [ 0  6 10] [0.015 0.105 0.764]
# sym21. Pred [ 0  6 10] [0.011 0.444 0.46 ]
# sym22. Pred [ 1 10  6] [0.049 0.062 0.745]
# sym23. Pred [ 6 10  1] [0.039 0.106 0.598]
# sym24. Pred [ 1 10  9] [0.041 0.106 0.597]
# sym25. Pred [ 1  9 10] [0.019 0.225 0.612]
# Tag id: bcbb7bca26e4ae9f64d06d78caf578f6d936caba
# True text: 460596601137 , Len: 12 , Pred text: 4605966001137 , Dist: 1
# Pred argmax 4446•0•5•9•6•600•01••13•7•
# sym0. Pred [ 6 10  4] [0.015 0.384 0.485]
# sym1. Pred [ 6 10  4] [0.021 0.054 0.795]
# sym2. Pred [10  6  4] [0.314 0.314 0.314]
# sym3. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym4. Pred [ 0  6 10] [0.313 0.313 0.315]
# sym5. Pred [ 6 10  0] [0.02  0.054 0.796]
# sym6. Pred [ 5  0 10] [0.313 0.313 0.315]
# sym7. Pred [ 0 10  5] [0.02  0.054 0.796]
# sym8. Pred [ 9  5 10] [0.176 0.376 0.378]
# sym9. Pred [ 5 10  9] [0.039 0.107 0.599]
# sym10. Pred [ 9  6 10] [0.146 0.384 0.396]
# sym11. Pred [ 0 10  6] [0.018 0.063 0.773]
# sym12. Pred [ 0  6 10] [0.019 0.066 0.772]
# sym13. Pred [ 0 10  6] [0.023 0.083 0.75 ]
# sym14. Pred [10  6  0] [0.036 0.438 0.441]
# sym15. Pred [ 6 10  0] [0.019 0.053 0.805]
# sym16. Pred [ 6  0 10] [0.019 0.062 0.775]
# sym17. Pred [ 1 10  0] [0.057 0.072 0.705]
# sym18. Pred [ 0 10  1] [0.04  0.107 0.604]
# sym19. Pred [ 0  1 10] [0.016 0.042 0.818]
# sym20. Pred [ 7  1 10] [0.014 0.278 0.597]
# sym21. Pred [ 7 10  1] [0.032 0.106 0.617]
# sym22. Pred [ 1 10  3] [0.064 0.169 0.362]
# sym23. Pred [ 3  7 10] [0.092 0.275 0.533]
# sym24. Pred [ 1 10  7] [0.016 0.054 0.799]
# sym25. Pred [ 8  7 10] [0.013 0.44  0.442]
# Tag id: 6012c4f80244d5c2a263d27cd19d333a88c8724d
# True text: 64607011430589 , Len: 14 , Pred text: 4607011430589 , Dist: 1
# Pred argmax •••4•6607•0•1•143•0•5•8•9•
# sym0. Pred [ 4  6 10] [0.024 0.027 0.768]
# sym1. Pred [ 4  6 10] [0.021 0.043 0.805]
# sym2. Pred [ 6  4 10] [0.051 0.434 0.434]
# sym3. Pred [ 6 10  4] [0.025 0.054 0.795]
# sym4. Pred [ 6  4 10] [0.313 0.313 0.315]
# sym5. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym6. Pred [10  0  6] [0.039 0.432 0.445]
# sym7. Pred [10  7  0] [0.061 0.061 0.732]
# sym8. Pred [ 0 10  7] [0.025 0.054 0.795]
# sym9. Pred [ 0  7 10] [0.313 0.313 0.315]
# sym10. Pred [ 7 10  0] [0.02  0.054 0.8  ]
# sym11. Pred [ 1  0 10] [0.144 0.39  0.392]
# sym12. Pred [ 0 10  1] [0.04  0.107 0.603]
# sym13. Pred [ 4  1 10] [0.02  0.05  0.784]
# sym14. Pred [ 4 10  1] [0.042 0.105 0.61 ]
# sym15. Pred [ 3 10  4] [0.034 0.073 0.717]
# sym16. Pred [ 0 10  3] [0.062 0.169 0.362]
# sym17. Pred [ 3  0 10] [0.073 0.423 0.425]
# sym18. Pred [ 5 10  0] [0.02  0.054 0.8  ]
# sym19. Pred [ 5  0 10] [0.313 0.313 0.315]
# sym20. Pred [ 0 10  5] [0.02  0.054 0.796]
# sym21. Pred [ 8  5 10] [0.313 0.313 0.315]
# sym22. Pred [ 5 10  8] [0.02  0.054 0.796]
# sym23. Pred [ 9  8 10] [0.175 0.376 0.378]
# sym24. Pred [ 8 10  9] [0.041 0.106 0.597]
# sym25. Pred [ 8  9 10] [0.019 0.225 0.612]
# Tag id: 8957f70ed3909dc4bebfb0038cfdd00dcdfda0ed
# True text: 07640170370072 , Len: 14 , Pred text: 7640170370072 , Dist: 1
# Pred argmax •••7•6•40017003•700••07•2•
# sym0. Pred [ 1  7 10] [0.023 0.024 0.771]
# sym1. Pred [ 0  7 10] [0.018 0.021 0.825]
# sym2. Pred [ 6  7 10] [0.011 0.452 0.452]
# sym3. Pred [ 6 10  7] [0.02  0.054 0.799]
# sym4. Pred [ 6  7 10] [0.313 0.313 0.315]
# sym5. Pred [ 4 10  6] [0.02  0.054 0.796]
# sym6. Pred [ 4  6 10] [0.312 0.312 0.316]
# sym7. Pred [ 6 10  4] [0.021 0.057 0.786]
# sym8. Pred [10  4  0] [0.058 0.112 0.695]
# sym9. Pred [10  1  0] [0.05  0.23  0.603]
# sym10. Pred [ 0 10  1] [0.041 0.106 0.598]
# sym11. Pred [ 0 10  7] [0.024 0.063 0.761]
# sym12. Pred [10  7  0] [0.041 0.437 0.437]
# sym13. Pred [ 7 10  0] [0.024 0.064 0.765]
# sym14. Pred [ 7 10  3] [0.064 0.169 0.362]
# sym15. Pred [ 3  7 10] [0.073 0.423 0.425]
# sym16. Pred [ 0 10  7] [0.02  0.054 0.8  ]
# sym17. Pred [ 7 10  0] [0.297 0.32  0.323]
# sym18. Pred [ 7 10  0] [0.028 0.052 0.798]
# sym19. Pred [ 7  0 10] [0.017 0.053 0.807]
# sym20. Pred [ 7  0 10] [0.011 0.443 0.46 ]
# sym21. Pred [10  7  0] [0.061 0.061 0.735]
# sym22. Pred [ 2 10  7] [0.02  0.054 0.796]
# sym23. Pred [ 2  7 10] [0.176 0.375 0.378]
# sym24. Pred [ 7 10  2] [0.041 0.106 0.597]
# sym25. Pred [ 7  2 10] [0.019 0.225 0.612]
# Tag id: c17f76bd43d2414661d33ab577ed3cc92f37de8e
# True text: 74680017724098 , Len: 14 , Pred text: 4680017724098 , Dist: 1
# Pred argmax ••44•68•0••017•72•4•0•9•8•
# sym0. Pred [ 4  7 10] [0.024 0.024 0.77 ]
# sym1. Pred [ 4  7 10] [0.022 0.022 0.822]
# sym2. Pred [ 7 10  4] [0.014 0.45  0.451]
# sym3. Pred [ 6 10  4] [0.02  0.054 0.796]
# sym4. Pred [ 4  6 10] [0.3   0.313 0.325]
# sym5. Pred [ 8 10  6] [0.033 0.063 0.753]
# sym6. Pred [ 6 10  8] [0.026 0.069 0.738]
# sym7. Pred [ 8  0 10] [0.301 0.32  0.32 ]
# sym8. Pred [ 8 10  0] [0.019 0.053 0.805]
# sym9. Pred [ 8  0 10] [0.016 0.053 0.808]
# sym10. Pred [ 7  0 10] [0.011 0.444 0.46 ]
# sym11. Pred [ 1 10  0] [0.049 0.062 0.745]
# sym12. Pred [ 7 10  1] [0.039 0.107 0.599]
# sym13. Pred [ 1 10  7] [0.027 0.074 0.726]
# sym14. Pred [ 2  7 10] [0.019 0.062 0.774]
# sym15. Pred [ 2 10  7] [0.023 0.064 0.765]
# sym16. Pred [ 4 10  2] [0.039 0.107 0.599]
# sym17. Pred [ 2  4 10] [0.145 0.389 0.393]
# sym18. Pred [ 0 10  4] [0.02  0.054 0.8  ]
# sym19. Pred [ 0  4 10] [0.313 0.313 0.315]
# sym20. Pred [ 4 10  0] [0.02  0.054 0.796]
# sym21. Pred [ 9  0 10] [0.175 0.376 0.378]
# sym22. Pred [ 0 10  9] [0.039 0.107 0.598]
# sym23. Pred [ 9  8 10] [0.144 0.389 0.393]
# sym24. Pred [ 0 10  8] [0.016 0.054 0.799]
# sym25. Pred [ 0  8 10] [0.013 0.44  0.442]
# Tag id: 7af5969c0a58a0f9719f6e6e01d434cc920cc0e1
# True text: 4601751016521 , Len: 13 , Pred text: 4601751016621 , Dist: 2
# Pred argmax 4446•0•1••7•5•1•0•1•6••621
# sym0. Pred [ 6 10  4] [0.015 0.384 0.485]
# sym1. Pred [ 6 10  4] [0.021 0.054 0.795]
# sym2. Pred [ 6 10  4] [0.314 0.314 0.314]
# sym3. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym4. Pred [ 6  0 10] [0.313 0.313 0.315]
# sym5. Pred [ 6 10  0] [0.02  0.054 0.8  ]
# sym6. Pred [ 1  0 10] [0.144 0.389 0.393]
# sym7. Pred [ 0 10  1] [0.039 0.107 0.603]
# sym8. Pred [ 7  1 10] [0.016 0.244 0.642]
# sym9. Pred [ 1  7 10] [0.013 0.45  0.452]
# sym10. Pred [ 5 10  7] [0.02  0.054 0.799]
# sym11. Pred [ 7  5 10] [0.313 0.313 0.315]
# sym12. Pred [ 7 10  5] [0.02  0.054 0.8  ]
# sym13. Pred [ 1  5 10] [0.144 0.39  0.392]
# sym14. Pred [ 5 10  1] [0.039 0.107 0.599]
# sym15. Pred [ 1  0 10] [0.176 0.376 0.378]
# sym16. Pred [ 1 10  0] [0.02  0.054 0.8  ]
# sym17. Pred [ 1  0 10] [0.144 0.39  0.392]
# sym18. Pred [ 6 10  1] [0.039 0.107 0.599]
# sym19. Pred [ 1  6 10] [0.176 0.376 0.378]
# sym20. Pred [ 1 10  6] [0.02  0.054 0.799]
# sym21. Pred [ 5  6 10] [0.015 0.106 0.762]
# sym22. Pred [ 2  6 10] [0.016 0.358 0.526]
# sym23. Pred [10  2  6] [0.148 0.249 0.255]
# sym24. Pred [ 1 10  2] [0.047 0.121 0.532]
# sym25. Pred [ 2 10  1] [0.064 0.153 0.33 ]
# Tag id: 72bf04a7a8f351757287bf69eb2bf89ca564be35
# True text: 251373300004 , Len: 12 , Pred text: 2513733000004 , Dist: 1
# Pred argmax •2•5•1•3•73••300••0•0•0•04
# sym0. Pred [ 5  2 10] [0.02  0.306 0.519]
# sym1. Pred [ 5 10  2] [0.041 0.106 0.597]
# sym2. Pred [ 2  5 10] [0.143 0.391 0.392]
# sym3. Pred [ 2 10  5] [0.017 0.054 0.803]
# sym4. Pred [ 1  5 10] [0.144 0.39  0.393]
# sym5. Pred [ 5 10  1] [0.04  0.107 0.604]
# sym6. Pred [ 3  1 10] [0.094 0.255 0.548]
# sym7. Pred [ 7 10  3] [0.062 0.169 0.363]
# sym8. Pred [ 3  7 10] [0.074 0.415 0.43 ]
# sym9. Pred [ 1 10  7] [0.019 0.064 0.769]
# sym10. Pred [ 7 10  3] [0.063 0.172 0.367]
# sym11. Pred [ 7  3 10] [0.018 0.107 0.76 ]
# sym12. Pred [ 0  3 10] [0.017 0.124 0.723]
# sym13. Pred [ 0 10  3] [0.063 0.172 0.367]
# sym14. Pred [ 3 10  0] [0.073 0.424 0.424]
# sym15. Pred [ 7 10  0] [0.015 0.053 0.809]
# sym16. Pred [ 2  0 10] [0.015 0.053 0.809]
# sym17. Pred [ 2  0 10] [0.011 0.453 0.453]
# sym18. Pred [ 4 10  0] [0.015 0.053 0.809]
# sym19. Pred [ 4  0 10] [0.018 0.062 0.775]
# sym20. Pred [ 4 10  0] [0.018 0.062 0.776]
# sym21. Pred [ 4  0 10] [0.018 0.062 0.776]
# sym22. Pred [ 4 10  0] [0.018 0.062 0.774]
# sym23. Pred [ 4  0 10] [0.019 0.062 0.774]
# sym24. Pred [10  4  0] [0.07  0.071 0.69 ]
# sym25. Pred [ 0 10  4] [0.028 0.061 0.731]
# Tag id: d3f9b07fe484a64196898f7a6fe33478d4bc3ec0
# True text: 4660001803213 , Len: 13 , Pred text: 54660001803213 , Dist: 1
# Pred argmax 5544•6••60•0••018003•2•13•
# sym0. Pred [ 4 10  5] [0.015 0.385 0.485]
# sym1. Pred [ 4 10  5] [0.021 0.055 0.794]
# sym2. Pred [ 5 10  4] [0.313 0.314 0.314]
# sym3. Pred [ 6 10  4] [0.02  0.054 0.796]
# sym4. Pred [ 6  4 10] [0.313 0.313 0.315]
# sym5. Pred [ 4 10  6] [0.02  0.055 0.797]
# sym6. Pred [ 0  6 10] [0.015 0.097 0.77 ]
# sym7. Pred [ 0  6 10] [0.014 0.442 0.459]
# sym8. Pred [10  0  6] [0.057 0.123 0.687]
# sym9. Pred [ 6 10  0] [0.019 0.053 0.805]
# sym10. Pred [ 6  0 10] [0.019 0.062 0.775]
# sym11. Pred [ 6 10  0] [0.018 0.062 0.775]
# sym12. Pred [ 6  0 10] [0.015 0.053 0.809]
# sym13. Pred [ 8  0 10] [0.011 0.444 0.46 ]
# sym14. Pred [ 1 10  0] [0.049 0.062 0.745]
# sym15. Pred [ 0 10  1] [0.041 0.106 0.598]
# sym16. Pred [ 0 10  8] [0.024 0.063 0.761]
# sym17. Pred [10  8  0] [0.037 0.439 0.439]
# sym18. Pred [ 8 10  0] [0.023 0.064 0.765]
# sym19. Pred [ 2 10  3] [0.062 0.169 0.362]
# sym20. Pred [ 3  2 10] [0.094 0.255 0.548]
# sym21. Pred [ 0 10  2] [0.032 0.108 0.609]
# sym22. Pred [ 1  2 10] [0.191 0.191 0.52 ]
# sym23. Pred [ 8 10  1] [0.032 0.108 0.608]
# sym24. Pred [ 1 10  3] [0.118 0.16  0.34 ]
# sym25. Pred [ 1  3 10] [0.026 0.12  0.69 ]
# Tag id: 19766f47654e631429cbd8a599cbe4d7f963bc80
# True text: 4604087002825 , Len: 13 , Pred text: 4604087002025 , Dist: 2
# Pred argmax 4446•0•4•0•8•7•0••02•0•2•5
# sym0. Pred [ 6 10  4] [0.015 0.384 0.485]
# sym1. Pred [ 6 10  4] [0.021 0.054 0.795]
# sym2. Pred [10  6  4] [0.314 0.314 0.314]
# sym3. Pred [ 4 10  6] [0.02  0.054 0.796]
# sym4. Pred [ 0  6 10] [0.313 0.313 0.315]
# sym5. Pred [ 4 10  0] [0.02  0.054 0.796]
# sym6. Pred [ 0  4 10] [0.313 0.313 0.315]
# sym7. Pred [ 0 10  4] [0.025 0.054 0.795]
# sym8. Pred [ 0  4 10] [0.313 0.313 0.315]
# sym9. Pred [ 8 10  0] [0.02  0.054 0.796]
# sym10. Pred [ 8  0 10] [0.313 0.313 0.315]
# sym11. Pred [ 0 10  8] [0.02  0.054 0.796]
# sym12. Pred [ 7  8 10] [0.313 0.313 0.315]
# sym13. Pred [ 0 10  7] [0.02  0.054 0.796]
# sym14. Pred [ 7  0 10] [0.313 0.314 0.314]
# sym15. Pred [ 7 10  0] [0.019 0.053 0.805]
# sym16. Pred [ 7  0 10] [0.016 0.053 0.808]
# sym17. Pred [ 2  0 10] [0.011 0.444 0.46 ]
# sym18. Pred [ 2 10  0] [0.023 0.064 0.765]
# sym19. Pred [ 0 10  2] [0.05  0.106 0.597]
# sym20. Pred [ 2  0 10] [0.145 0.389 0.393]
# sym21. Pred [ 2 10  0] [0.02  0.054 0.8  ]
# sym22. Pred [ 2  0 10] [0.176 0.376 0.378]
# sym23. Pred [ 0 10  2] [0.039 0.106 0.598]
# sym24. Pred [ 2  5 10] [0.146 0.382 0.396]
# sym25. Pred [ 0 10  5] [0.023 0.061 0.736]
# Tag id: 5c04b45bdd0a69e4f0632bae534e240594f6917b
# True text: 796174 , Len: 6 , Pred text: 101163 , Dist: 10
# Pred argmax •1•0•1••16•3••••••••••••••
# sym0. Pred [ 1  2 10] [0.034 0.04  0.712]
# sym1. Pred [ 2 10  1] [0.129 0.164 0.296]
# sym2. Pred [ 1  0 10] [0.025 0.293 0.573]
# sym3. Pred [ 9 10  0] [0.024 0.061 0.775]
# sym4. Pred [ 1  0 10] [0.138 0.391 0.396]
# sym5. Pred [ 0 10  1] [0.039 0.107 0.602]
# sym6. Pred [ 6  1 10] [0.019 0.047 0.809]
# sym7. Pred [ 6  1 10] [0.015 0.252 0.618]
# sym8. Pred [ 6 10  1] [0.039 0.106 0.604]
# sym9. Pred [10  3  6] [0.082 0.154 0.55 ]
# sym10. Pred [ 3  6 10] [0.077 0.352 0.451]
# sym11. Pred [ 6 10  3] [0.145 0.165 0.314]
# sym12. Pred [ 4  3 10] [0.034 0.067 0.779]
# sym13. Pred [ 6  4 10] [0.017 0.018 0.842]
# sym14. Pred [ 6  4 10] [0.016 0.016 0.845]
# sym15. Pred [ 6  4 10] [0.016 0.016 0.845]
# sym16. Pred [ 6  4 10] [0.015 0.015 0.845]
# sym17. Pred [ 6  4 10] [0.015 0.015 0.845]
# sym18. Pred [ 0  4 10] [0.015 0.015 0.845]
# sym19. Pred [ 4  0 10] [0.015 0.015 0.845]
# sym20. Pred [ 5  0 10] [0.015 0.015 0.845]
# sym21. Pred [ 0  5 10] [0.015 0.015 0.845]
# sym22. Pred [ 0  5 10] [0.015 0.015 0.845]
# sym23. Pred [ 0  5 10] [0.016 0.016 0.844]
# sym24. Pred [ 0  5 10] [0.016 0.016 0.836]
# sym25. Pred [ 0  5 10] [0.023 0.023 0.772]
# Tag id: dc9b91f7b39552364895a116e59147ac7f9f5894
# True text: 4607064610871 , Len: 13 , Pred text: 4607064810871 , Dist: 2
# Pred argmax 4446•0•7•0•6•4•8•1•0•8•7•1
# sym0. Pred [ 6 10  4] [0.015 0.384 0.485]
# sym1. Pred [ 6 10  4] [0.021 0.054 0.795]
# sym2. Pred [10  6  4] [0.314 0.314 0.314]
# sym3. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym4. Pred [ 6  0 10] [0.313 0.313 0.315]
# sym5. Pred [ 6 10  0] [0.02  0.054 0.796]
# sym6. Pred [ 0  7 10] [0.313 0.313 0.315]
# sym7. Pred [ 0 10  7] [0.025 0.054 0.795]
# sym8. Pred [ 0  7 10] [0.313 0.313 0.315]
# sym9. Pred [ 6 10  0] [0.02  0.054 0.796]
# sym10. Pred [ 6  0 10] [0.313 0.313 0.315]
# sym11. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym12. Pred [ 4  6 10] [0.313 0.313 0.315]
# sym13. Pred [ 8 10  4] [0.02  0.054 0.796]
# sym14. Pred [ 8  4 10] [0.312 0.314 0.315]
# sym15. Pred [ 4 10  8] [0.02  0.054 0.8  ]
# sym16. Pred [ 1  8 10] [0.144 0.39  0.392]
# sym17. Pred [ 8 10  1] [0.039 0.107 0.598]
# sym18. Pred [ 1  0 10] [0.175 0.376 0.378]
# sym19. Pred [ 8 10  0] [0.02  0.054 0.796]
# sym20. Pred [ 8  0 10] [0.313 0.313 0.315]
# sym21. Pred [ 0 10  8] [0.02  0.054 0.796]
# sym22. Pred [ 7  8 10] [0.313 0.313 0.315]
# sym23. Pred [ 8 10  7] [0.02  0.054 0.799]
# sym24. Pred [ 1  7 10] [0.144 0.389 0.391]
# sym25. Pred [ 7 10  1] [0.047 0.1   0.56 ]
# Tag id: 890af800797cfe9a8523456d26654f087a7df8f8
# True text: 203930 , Len: 6 , Pred text: 2039300 , Dist: 1
# Pred argmax •2••••0••3•••9••3•••0•••0•
# sym0. Pred [ 0  2 10] [0.019 0.306 0.519]
# sym1. Pred [ 0 10  2] [0.032 0.107 0.603]
# sym2. Pred [ 0  2 10] [0.013 0.2   0.686]
# sym3. Pred [ 2  0 10] [0.016 0.016 0.844]
# sym4. Pred [ 2  0 10] [0.016 0.02  0.837]
# sym5. Pred [ 2  0 10] [0.011 0.451 0.454]
# sym6. Pred [ 9 10  0] [0.016 0.055 0.803]
# sym7. Pred [ 9  0 10] [0.01  0.41  0.504]
# sym8. Pred [ 0  3 10] [0.021 0.124 0.721]
# sym9. Pred [ 0 10  3] [0.052 0.174 0.372]
# sym10. Pred [ 9  3 10] [0.015 0.104 0.768]
# sym11. Pred [ 0  9 10] [0.016 0.02  0.837]
# sym12. Pred [ 0  9 10] [0.014 0.278 0.597]
# sym13. Pred [ 0 10  9] [0.031 0.108 0.609]
# sym14. Pred [ 0  9 10] [0.013 0.204 0.68 ]
# sym15. Pred [ 0  3 10] [0.017 0.124 0.724]
# sym16. Pred [ 0 10  3] [0.051 0.174 0.372]
# sym17. Pred [ 0  3 10] [0.015 0.104 0.768]
# sym18. Pred [ 6  0 10] [0.016 0.02  0.837]
# sym19. Pred [ 6  0 10] [0.011 0.451 0.454]
# sym20. Pred [ 6 10  0] [0.016 0.055 0.803]
# sym21. Pred [ 6  0 10] [0.01  0.403 0.512]
# sym22. Pred [ 6  0 10] [0.018 0.023 0.832]
# sym23. Pred [ 6  0 10] [0.022 0.041 0.789]
# sym24. Pred [ 6 10  0] [0.058 0.138 0.475]
# sym25. Pred [ 6  0 10] [0.024 0.057 0.744]
# Tag id: c637e06aa8a443a876bbf9cfddbf3051ef4f7022
# True text: 3600542146616 , Len: 13 , Pred text: 3600542148616 , Dist: 2
# Pred argmax •3•600••05•4•2•14•8•661•6•
# sym0. Pred [ 6  3 10] [0.022 0.259 0.554]
# sym1. Pred [ 6 10  3] [0.064 0.169 0.361]
# sym2. Pred [ 3  6 10] [0.073 0.423 0.424]
# sym3. Pred [ 0 10  6] [0.02  0.054 0.8  ]
# sym4. Pred [ 6 10  0] [0.313 0.314 0.314]
# sym5. Pred [ 6 10  0] [0.019 0.053 0.805]
# sym6. Pred [ 6  0 10] [0.016 0.053 0.808]
# sym7. Pred [ 5  0 10] [0.011 0.444 0.46 ]
# sym8. Pred [10  5  0] [0.061 0.061 0.735]
# sym9. Pred [ 4 10  5] [0.02  0.054 0.796]
# sym10. Pred [ 4  5 10] [0.313 0.313 0.315]
# sym11. Pred [ 2 10  4] [0.02  0.054 0.796]
# sym12. Pred [ 2  4 10] [0.176 0.376 0.378]
# sym13. Pred [ 4 10  2] [0.04  0.107 0.603]
# sym14. Pred [ 1  2 10] [0.191 0.191 0.52 ]
# sym15. Pred [ 4 10  1] [0.04  0.107 0.603]
# sym16. Pred [ 8 10  4] [0.023 0.063 0.761]
# sym17. Pred [ 8  4 10] [0.259 0.332 0.344]
# sym18. Pred [ 4 10  8] [0.02  0.054 0.796]
# sym19. Pred [ 6  8 10] [0.068 0.424 0.428]
# sym20. Pred [ 8 10  6] [0.038 0.056 0.778]
# sym21. Pred [ 1 10  6] [0.088 0.279 0.531]
# sym22. Pred [ 6 10  1] [0.05  0.106 0.596]
# sym23. Pred [ 1  6 10] [0.208 0.261 0.447]
# sym24. Pred [ 1 10  6] [0.021 0.054 0.795]
# sym25. Pred [ 1  6 10] [0.014 0.44  0.442]
# Tag id: da61ae390fc8fdb2a2ff9fef5b9b20bc26742b56
# True text: 4607031149522 , Len: 13 , Pred text: 460703114522 , Dist: 1
# Pred argmax 4466•0•7703•1••1445552••2•
# sym0. Pred [ 6 10  4] [0.015 0.384 0.485]
# sym1. Pred [ 6 10  4] [0.021 0.054 0.795]
# sym2. Pred [10  4  6] [0.314 0.314 0.314]
# sym3. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym4. Pred [ 6  0 10] [0.313 0.313 0.315]
# sym5. Pred [ 7 10  0] [0.02  0.054 0.796]
# sym6. Pred [ 7  0 10] [0.313 0.313 0.315]
# sym7. Pred [ 0 10  7] [0.025 0.054 0.795]
# sym8. Pred [ 0 10  7] [0.308 0.315 0.318]
# sym9. Pred [ 7 10  0] [0.023 0.064 0.765]
# sym10. Pred [ 0 10  3] [0.063 0.171 0.367]
# sym11. Pred [ 3  1 10] [0.099 0.213 0.579]
# sym12. Pred [ 0 10  1] [0.032 0.108 0.609]
# sym13. Pred [ 4  1 10] [0.016 0.042 0.818]
# sym14. Pred [ 4  1 10] [0.014 0.278 0.596]
# sym15. Pred [ 4 10  1] [0.039 0.105 0.611]
# sym16. Pred [ 9 10  4] [0.027 0.073 0.725]
# sym17. Pred [10  9  4] [0.063 0.362 0.425]
# sym18. Pred [10  9  5] [0.206 0.241 0.448]
# sym19. Pred [10  9  5] [0.051 0.085 0.742]
# sym20. Pred [10  2  5] [0.049 0.237 0.601]
# sym21. Pred [ 5 10  2] [0.039 0.105 0.612]
# sym22. Pred [ 5  2 10] [0.015 0.129 0.744]
# sym23. Pred [ 5  2 10] [0.014 0.277 0.597]
# sym24. Pred [ 5 10  2] [0.032 0.107 0.603]
# sym25. Pred [ 5  2 10] [0.018 0.225 0.612]
# Tag id: a13c1f36d90c260fbba290f4b3f1dd24fa4dbae2
# True text: 4690363078370 , Len: 13 , Pred text: 4690563078370 , Dist: 2
# Pred argmax 4466•9•0•5•6•3007•8•3•7•0•
# sym0. Pred [ 6 10  4] [0.015 0.384 0.485]
# sym1. Pred [ 6 10  4] [0.021 0.054 0.795]
# sym2. Pred [10  4  6] [0.314 0.314 0.314]
# sym3. Pred [ 9 10  6] [0.02  0.054 0.796]
# sym4. Pred [ 9  6 10] [0.176 0.376 0.378]
# sym5. Pred [ 6 10  9] [0.039 0.107 0.598]
# sym6. Pred [ 9  0 10] [0.144 0.39  0.392]
# sym7. Pred [ 5 10  0] [0.02  0.054 0.8  ]
# sym8. Pred [ 5  0 10] [0.224 0.333 0.334]
# sym9. Pred [10  3  5] [0.052 0.109 0.711]
# sym10. Pred [ 5  6 10] [0.254 0.319 0.32 ]
# sym11. Pred [ 5 10  6] [0.02  0.054 0.799]
# sym12. Pred [ 3  6 10] [0.073 0.422 0.424]
# sym13. Pred [ 0 10  3] [0.062 0.169 0.362]
# sym14. Pred [10  3  0] [0.057 0.122 0.685]
# sym15. Pred [10  7  0] [0.061 0.061 0.735]
# sym16. Pred [ 8 10  7] [0.02  0.054 0.796]
# sym17. Pred [ 8  7 10] [0.313 0.313 0.315]
# sym18. Pred [ 7 10  8] [0.02  0.054 0.8  ]
# sym19. Pred [ 3  8 10] [0.073 0.423 0.425]
# sym20. Pred [ 7 10  3] [0.063 0.169 0.362]
# sym21. Pred [ 3  7 10] [0.073 0.423 0.425]
# sym22. Pred [ 0 10  7] [0.02  0.054 0.8  ]
# sym23. Pred [ 0  7 10] [0.313 0.313 0.315]
# sym24. Pred [ 7 10  0] [0.021 0.054 0.796]
# sym25. Pred [ 7  0 10] [0.014 0.44  0.442]
# Tag id: 831954472ae21e88368e60c9d77c39e916fdd8a8
# True text: 194548 , Len: 6 , Pred text: 194648 , Dist: 2
# Pred argmax •1••••9•••44••6•••4•••••8•
# sym0. Pred [ 9  1 10] [0.021 0.259 0.554]
# sym1. Pred [ 9 10  1] [0.032 0.107 0.603]
# sym2. Pred [ 9  1 10] [0.012 0.24  0.652]
# sym3. Pred [ 9  1 10] [0.016 0.02  0.84 ]
# sym4. Pred [ 1  9 10] [0.016 0.02  0.836]
# sym5. Pred [ 1  9 10] [0.014 0.278 0.597]
# sym6. Pred [ 4 10  9] [0.032 0.108 0.609]
# sym7. Pred [ 4  9 10] [0.013 0.2   0.686]
# sym8. Pred [ 6  4 10] [0.016 0.02  0.837]
# sym9. Pred [ 6  4 10] [0.011 0.452 0.453]
# sym10. Pred [ 6 10  4] [0.016 0.053 0.808]
# sym11. Pred [ 6 10  4] [0.016 0.058 0.802]
# sym12. Pred [ 6  4 10] [0.012 0.408 0.503]
# sym13. Pred [ 4  6 10] [0.016 0.357 0.527]
# sym14. Pred [ 5 10  6] [0.038 0.055 0.78 ]
# sym15. Pred [ 5  6 10] [0.013 0.313 0.587]
# sym16. Pred [ 4  6 10] [0.02  0.021 0.833]
# sym17. Pred [ 6  4 10] [0.011 0.451 0.453]
# sym18. Pred [ 6 10  4] [0.016 0.055 0.803]
# sym19. Pred [ 6  4 10] [0.009 0.402 0.513]
# sym20. Pred [ 8  4 10] [0.016 0.02  0.842]
# sym21. Pred [ 8  4 10] [0.016 0.016 0.844]
# sym22. Pred [ 4  8 10] [0.016 0.02  0.837]
# sym23. Pred [ 4  8 10] [0.011 0.451 0.453]
# ...
# sym16. Pred [10  3  4] [0.057 0.122 0.687]
# sym17. Pred [ 4 10  3] [0.062 0.169 0.362]
# sym18. Pred [ 2 10  9] [0.04  0.107 0.603]
# sym19. Pred [ 9  2 10] [0.182 0.231 0.495]
# sym20. Pred [ 4 10  2] [0.031 0.106 0.617]
# sym21. Pred [ 4  2 10] [0.014 0.107 0.763]
# sym22. Pred [ 8  2 10] [0.014 0.278 0.597]
# sym23. Pred [ 8 10  2] [0.032 0.108 0.608]
# sym24. Pred [ 3  2 10] [0.102 0.185 0.596]
# sym25. Pred [10  1  3] [0.136 0.175 0.282]
# Tag id: ac090f113be3a1ae3b72fc2967aaa7342639437b
# True text: 4008429090110 , Len: 13 , Pred text: 400842900110 , Dist: 1
# Pred argmax 4400••0•8442•9•00•0•1••10•
# sym0. Pred [ 0 10  4] [0.015 0.384 0.485]
# sym1. Pred [ 0 10  4] [0.021 0.054 0.796]
# sym2. Pred [10  4  0] [0.313 0.313 0.315]
# sym3. Pred [ 4 10  0] [0.019 0.053 0.805]
# sym4. Pred [ 4  0 10] [0.016 0.053 0.808]
# sym5. Pred [ 8  0 10] [0.011 0.451 0.453]
# sym6. Pred [ 8 10  0] [0.02  0.054 0.8  ]
# sym7. Pred [ 8  0 10] [0.313 0.313 0.315]
# sym8. Pred [ 4 10  8] [0.02  0.054 0.796]
# sym9. Pred [10  8  4] [0.037 0.434 0.441]
# sym10. Pred [ 2 10  4] [0.034 0.063 0.753]
# sym11. Pred [ 9 10  2] [0.039 0.106 0.598]
# sym12. Pred [ 2  9 10] [0.182 0.23  0.495]
# sym13. Pred [ 0 10  9] [0.04  0.107 0.604]
# sym14. Pred [ 9  0 10] [0.145 0.387 0.394]
# sym15. Pred [ 9 10  0] [0.022 0.059 0.784]
# sym16. Pred [10  9  0] [0.068 0.383 0.391]
# sym17. Pred [ 9  0 10] [0.222 0.249 0.416]
# sym18. Pred [ 9 10  0] [0.019 0.054 0.801]
# sym19. Pred [ 1  0 10] [0.144 0.39  0.392]
# sym20. Pred [ 0 10  1] [0.04  0.107 0.604]
# sym21. Pred [ 0  1 10] [0.016 0.042 0.817]
# sym22. Pred [ 0  1 10] [0.014 0.278 0.596]
# sym23. Pred [ 0 10  1] [0.039 0.105 0.611]
# sym24. Pred [ 1 10  0] [0.024 0.063 0.761]
# sym25. Pred [ 1  0 10] [0.014 0.432 0.448]
# Tag id: da386f42f666c8de75cadb35f799495ce7575f96
# True text: 1306865 , Len: 7 , Pred text: 106865 , Dist: 1
# Pred argmax •1•••••••0••6••8•••6••••5•
# sym0. Pred [ 7  1 10] [0.021 0.259 0.554]
# sym1. Pred [ 0 10  1] [0.032 0.107 0.603]
# sym2. Pred [ 3  1 10] [0.012 0.241 0.65 ]
# sym3. Pred [ 1  3 10] [0.018 0.107 0.759]
# sym4. Pred [ 1  3 10] [0.018 0.126 0.719]
# sym5. Pred [ 1  3 10] [0.021 0.153 0.66 ]
# sym6. Pred [ 0  3 10] [0.015 0.07  0.797]
# sym7. Pred [ 6  0 10] [0.016 0.02  0.837]
# sym8. Pred [ 6  0 10] [0.011 0.451 0.454]
# sym9. Pred [ 6 10  0] [0.016 0.055 0.803]
# sym10. Pred [ 6  0 10] [0.012 0.409 0.503]
# sym11. Pred [ 0  6 10] [0.013 0.45  0.452]
# sym12. Pred [ 0 10  6] [0.016 0.054 0.802]
# sym13. Pred [ 8  6 10] [0.012 0.409 0.503]
# sym14. Pred [ 6  8 10] [0.013 0.45  0.452]
# sym15. Pred [ 6 10  8] [0.016 0.055 0.803]
# sym16. Pred [ 6  8 10] [0.01  0.403 0.512]
# sym17. Pred [ 8  6 10] [0.02  0.02  0.833]
# sym18. Pred [ 8  6 10] [0.011 0.451 0.453]
# sym19. Pred [ 8 10  6] [0.016 0.055 0.803]
# sym20. Pred [ 5  6 10] [0.009 0.402 0.513]
# sym21. Pred [ 5  6 10] [0.016 0.02  0.841]
# sym22. Pred [ 6  5 10] [0.016 0.02  0.836]
# sym23. Pred [ 6  5 10] [0.011 0.451 0.453]
# sym24. Pred [ 6 10  5] [0.016 0.054 0.799]
# sym25. Pred [ 6  5 10] [0.013 0.44  0.442]
# Tag id: dd48b5b2871e7f180fc21e770ecd0fe9bb352a5d
# True text: 4603260030952 , Len: 13 , Pred text: 460326030952 , Dist: 1
# Pred argmax 4446•0•3•2•6•0•••3•0•9•52•
# sym0. Pred [ 6 10  4] [0.015 0.384 0.485]
# sym1. Pred [ 6 10  4] [0.021 0.054 0.795]
# sym2. Pred [10  6  4] [0.314 0.314 0.314]
# sym3. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym4. Pred [ 6  0 10] [0.313 0.313 0.315]
# sym5. Pred [ 6 10  0] [0.02  0.054 0.8  ]
# sym6. Pred [ 3  0 10] [0.073 0.423 0.425]
# sym7. Pred [ 0 10  3] [0.062 0.169 0.362]
# sym8. Pred [ 3  2 10] [0.094 0.255 0.548]
# sym9. Pred [ 6 10  2] [0.04  0.107 0.604]
# sym10. Pred [ 2  6 10] [0.144 0.39  0.392]
# sym11. Pred [ 0 10  6] [0.02  0.054 0.8  ]
# sym12. Pred [ 0  6 10] [0.313 0.313 0.315]
# sym13. Pred [ 6 10  0] [0.02  0.054 0.8  ]
# sym14. Pred [ 1  0 10] [0.015 0.45  0.451]
# sym15. Pred [ 0  1 10] [0.076 0.184 0.261]
# sym16. Pred [ 1  3 10] [0.021 0.124 0.72 ]
# sym17. Pred [ 0 10  3] [0.063 0.169 0.362]
# sym18. Pred [ 3  0 10] [0.073 0.423 0.425]
# sym19. Pred [ 9 10  0] [0.02  0.054 0.8  ]
# sym20. Pred [ 9  0 10] [0.176 0.376 0.378]
# sym21. Pred [ 0 10  9] [0.039 0.107 0.599]
# sym22. Pred [ 9  5 10] [0.146 0.383 0.397]
# sym23. Pred [ 2 10  5] [0.023 0.064 0.765]
# sym24. Pred [ 5 10  2] [0.041 0.106 0.597]
# sym25. Pred [ 5  2 10] [0.019 0.225 0.612]
# Tag id: 7e6feb231ea6278eb952ac8bda8a0f2f65ff5d5b
# True text: 04604386012273 , Len: 14 , Pred text: 460438601273 , Dist: 2
# Pred argmax •••4•66004•3886•0•12••77•3
# sym0. Pred [ 4  0 10] [0.023 0.116 0.689]
# sym1. Pred [ 4  0 10] [0.028 0.348 0.476]
# sym2. Pred [ 0  4 10] [0.104 0.392 0.424]
# sym3. Pred [ 6 10  4] [0.021 0.054 0.795]
# sym4. Pred [ 4  6 10] [0.311 0.313 0.316]
# sym5. Pred [ 4 10  6] [0.025 0.054 0.792]
# sym6. Pred [ 0 10  6] [0.191 0.363 0.374]
# sym7. Pred [10  6  0] [0.052 0.053 0.766]
# sym8. Pred [10  4  0] [0.148 0.214 0.537]
# sym9. Pred [ 0 10  4] [0.02  0.054 0.8  ]
# sym10. Pred [ 3  4 10] [0.073 0.423 0.425]
# sym11. Pred [ 4 10  3] [0.062 0.169 0.362]
# sym12. Pred [10  3  8] [0.058 0.109 0.694]
# sym13. Pred [10  6  8] [0.053 0.188 0.636]
# sym14. Pred [ 8 10  6] [0.025 0.054 0.792]
# sym15. Pred [ 0  6 10] [0.313 0.313 0.315]
# sym16. Pred [ 6 10  0] [0.02  0.054 0.8  ]
# sym17. Pred [ 1  0 10] [0.144 0.39  0.392]
# sym18. Pred [ 0 10  1] [0.039 0.107 0.599]
# sym19. Pred [ 1 10  2] [0.039 0.107 0.603]
# sym20. Pred [ 7  2 10] [0.015 0.087 0.778]
# sym21. Pred [ 7  2 10] [0.025 0.38  0.437]
# sym22. Pred [10  2  7] [0.071 0.245 0.556]
# sym23. Pred [ 2 10  7] [0.022 0.056 0.792]
# sym24. Pred [ 3  7 10] [0.073 0.42  0.424]
# sym25. Pred [ 7 10  3] [0.071 0.153 0.327]
# Tag id: 216ca6fd2475a74fcc9adc79cab93f74e7569cb6
# True text: 40804897 , Len: 8 , Pred text: 40804397 , Dist: 2
# Pred argmax 44••0••8••0••4••3•••9•••7•
# sym0. Pred [ 0 10  4] [0.014 0.385 0.486]
# sym1. Pred [ 0 10  4] [0.017 0.054 0.799]
# sym2. Pred [ 0  4 10] [0.012 0.41  0.501]
# sym3. Pred [ 4  0 10] [0.013 0.45  0.452]
# sym4. Pred [ 8 10  0] [0.016 0.054 0.802]
# sym5. Pred [ 8  0 10] [0.012 0.409 0.503]
# sym6. Pred [ 0  8 10] [0.013 0.45  0.452]
# sym7. Pred [ 0 10  8] [0.017 0.054 0.802]
# sym8. Pred [ 0  8 10] [0.012 0.409 0.503]
# sym9. Pred [ 8  0 10] [0.013 0.45  0.452]
# sym10. Pred [ 4 10  0] [0.016 0.054 0.802]
# sym11. Pred [ 4  0 10] [0.012 0.409 0.503]
# sym12. Pred [ 0  4 10] [0.013 0.45  0.452]
# sym13. Pred [ 0 10  4] [0.016 0.055 0.803]
# sym14. Pred [ 3  4 10] [0.01  0.409 0.504]
# sym15. Pred [ 4  3 10] [0.021 0.124 0.721]
# sym16. Pred [ 8 10  3] [0.053 0.173 0.371]
# sym17. Pred [ 8  3 10] [0.018 0.104 0.765]
# sym18. Pred [ 8  9 10] [0.017 0.02  0.836]
# sym19. Pred [ 8  9 10] [0.014 0.278 0.597]
# sym20. Pred [ 7 10  9] [0.032 0.108 0.609]
# sym21. Pred [ 7  9 10] [0.013 0.2   0.686]
# sym22. Pred [ 8  7 10] [0.016 0.02  0.837]
# sym23. Pred [ 9  7 10] [0.011 0.451 0.453]
# sym24. Pred [ 6 10  7] [0.016 0.054 0.799]
# sym25. Pred [ 6  7 10] [0.013 0.44  0.442]
# Tag id: 48179dc84012be51ba7371318660f07e8c813e12
# True text: 4850017004852 , Len: 13 , Pred text: 4650017004852 , Dist: 2
# Pred argmax 4446•5•0••0•17•0••04•8•52•
# sym0. Pred [ 6 10  4] [0.015 0.384 0.485]
# sym1. Pred [ 6 10  4] [0.021 0.054 0.795]
# sym2. Pred [ 6 10  4] [0.313 0.314 0.314]
# sym3. Pred [ 5 10  6] [0.02  0.054 0.796]
# sym4. Pred [ 6  5 10] [0.305 0.317 0.318]
# sym5. Pred [ 0 10  5] [0.02  0.054 0.796]
# sym6. Pred [ 5  0 10] [0.312 0.314 0.314]
# sym7. Pred [ 5 10  0] [0.019 0.053 0.805]
# sym8. Pred [ 5  0 10] [0.016 0.053 0.808]
# sym9. Pred [ 5  0 10] [0.011 0.451 0.454]
# sym10. Pred [ 7 10  0] [0.016 0.055 0.803]
# sym11. Pred [ 1  0 10] [0.144 0.39  0.392]
# sym12. Pred [ 0 10  1] [0.041 0.106 0.598]
# sym13. Pred [ 0 10  7] [0.024 0.063 0.761]
# sym14. Pred [ 7  0 10] [0.306 0.317 0.317]
# sym15. Pred [ 7 10  0] [0.019 0.053 0.805]
# sym16. Pred [ 7  0 10] [0.016 0.053 0.808]
# sym17. Pred [ 4  0 10] [0.011 0.444 0.46 ]
# sym18. Pred [10  4  0] [0.061 0.061 0.735]
# sym19. Pred [ 0 10  4] [0.02  0.054 0.796]
# sym20. Pred [ 8  4 10] [0.313 0.313 0.315]
# sym21. Pred [ 4 10  8] [0.02  0.054 0.796]
# sym22. Pred [ 5  8 10] [0.306 0.316 0.318]
# sym23. Pred [ 8 10  5] [0.023 0.063 0.761]
# sym24. Pred [ 5 10  2] [0.041 0.106 0.597]
# sym25. Pred [ 5  2 10] [0.019 0.225 0.612]
# Tag id: bd1c900276258abc9dfd21a2dfdc523ff2a512e8
# True text: 04607001850038 , Len: 14 , Pred text: 4607001850038 , Dist: 1
# Pred argmax •••4•6007•0••018500••03•8•
# sym0. Pred [ 4  0 10] [0.022 0.094 0.714]
# sym1. Pred [ 4  0 10] [0.023 0.315 0.517]
# sym2. Pred [ 0  4 10] [0.073 0.424 0.424]
# sym3. Pred [ 0 10  4] [0.02  0.054 0.796]
# sym4. Pred [ 6  4 10] [0.313 0.313 0.315]
# sym5. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym6. Pred [10  6  0] [0.037 0.435 0.442]
# sym7. Pred [10  7  0] [0.061 0.061 0.732]
# sym8. Pred [ 0 10  7] [0.025 0.054 0.795]
# sym9. Pred [ 7  0 10] [0.313 0.314 0.314]
# sym10. Pred [ 7 10  0] [0.019 0.053 0.805]
# sym11. Pred [ 7  0 10] [0.016 0.053 0.808]
# sym12. Pred [ 8  0 10] [0.011 0.444 0.46 ]
# sym13. Pred [ 1 10  0] [0.049 0.062 0.745]
# sym14. Pred [ 0 10  1] [0.039 0.106 0.598]
# sym15. Pred [ 5 10  8] [0.034 0.073 0.717]
# sym16. Pred [ 0 10  5] [0.023 0.063 0.761]
# sym17. Pred [10  5  0] [0.093 0.407 0.421]
# sym18. Pred [ 5 10  0] [0.019 0.053 0.805]
# sym19. Pred [ 5  0 10] [0.016 0.053 0.808]
# sym20. Pred [ 8  0 10] [0.011 0.444 0.46 ]
# sym21. Pred [ 8 10  0] [0.019 0.064 0.769]
# sym22. Pred [ 0 10  3] [0.062 0.169 0.363]
# sym23. Pred [ 3  8 10] [0.074 0.418 0.428]
# sym24. Pred [ 0 10  8] [0.016 0.054 0.799]
# sym25. Pred [ 0  8 10] [0.013 0.44  0.442]
# Tag id: 321dc08d1bc1a5c42c5c7c146bddf4d44c0f17e4
# True text: 4607163090846 , Len: 13 , Pred text: 4607163090816 , Dist: 2
# Pred argmax 4446•0•7•1663•0•9•0•8•1•6•
# sym0. Pred [ 6 10  4] [0.015 0.384 0.485]
# sym1. Pred [ 6 10  4] [0.021 0.054 0.795]
# sym2. Pred [10  6  4] [0.314 0.314 0.314]
# sym3. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym4. Pred [ 6  0 10] [0.313 0.313 0.315]
# sym5. Pred [ 6 10  0] [0.02  0.054 0.796]
# sym6. Pred [ 7  0 10] [0.313 0.313 0.315]
# sym7. Pred [ 0 10  7] [0.02  0.054 0.8  ]
# sym8. Pred [ 1  7 10] [0.144 0.39  0.392]
# sym9. Pred [ 6 10  1] [0.039 0.107 0.599]
# sym10. Pred [ 1 10  6] [0.028 0.063 0.761]
# sym11. Pred [10  3  6] [0.057 0.122 0.686]
# sym12. Pred [ 0 10  3] [0.062 0.169 0.362]
# sym13. Pred [ 3  0 10] [0.073 0.423 0.425]
# sym14. Pred [ 9 10  0] [0.02  0.054 0.8  ]
# sym15. Pred [ 9  0 10] [0.176 0.376 0.378]
# sym16. Pred [ 0 10  9] [0.05  0.106 0.597]
# sym17. Pred [ 9  0 10] [0.144 0.39  0.392]
# sym18. Pred [ 8 10  0] [0.023 0.054 0.797]
# sym19. Pred [ 8  0 10] [0.312 0.314 0.315]
# sym20. Pred [ 0 10  8] [0.02  0.054 0.796]
# sym21. Pred [ 1  8 10] [0.064 0.406 0.408]
# sym22. Pred [ 4 10  1] [0.083 0.102 0.561]
# sym23. Pred [ 1  6 10] [0.175 0.374 0.377]
# sym24. Pred [ 1 10  6] [0.021 0.054 0.795]
# sym25. Pred [ 1  6 10] [0.014 0.44  0.442]
# Tag id: 20392d9d4b0fa449fa9d3029ee37463b4a0aca88
# True text: 54650068620229 , Len: 14 , Pred text: 4650068620229 , Dist: 1
# Pred argmax •••4•6500••06•8662002••29•
# sym0. Pred [ 4  5 10] [0.015 0.401 0.472]
# sym1. Pred [ 4  5 10] [0.013 0.408 0.497]
# sym2. Pred [ 5  4 10] [0.248 0.344 0.344]
# sym3. Pred [ 5 10  4] [0.027 0.054 0.791]
# sym4. Pred [ 6  4 10] [0.306 0.316 0.318]
# sym5. Pred [ 5 10  6] [0.024 0.063 0.761]
# sym6. Pred [ 0 10  5] [0.023 0.063 0.761]
# sym7. Pred [10  5  0] [0.309 0.31  0.321]
# sym8. Pred [ 5 10  0] [0.019 0.053 0.805]
# sym9. Pred [ 5  0 10] [0.016 0.053 0.808]
# sym10. Pred [ 6  0 10] [0.011 0.444 0.46 ]
# sym11. Pred [10  6  0] [0.057 0.119 0.69 ]
# sym12. Pred [ 0 10  6] [0.02  0.054 0.795]
# sym13. Pred [ 6  8 10] [0.313 0.313 0.315]
# sym14. Pred [ 6 10  8] [0.025 0.054 0.794]
# sym15. Pred [10  8  6] [0.054 0.17  0.647]
# sym16. Pred [10  2  6] [0.052 0.211 0.616]
# sym17. Pred [ 0 10  2] [0.039 0.107 0.598]
# sym18. Pred [10  2  0] [0.057 0.228 0.599]
# sym19. Pred [ 2 10  0] [0.025 0.064 0.764]
# sym20. Pred [ 0 10  2] [0.039 0.105 0.612]
# sym21. Pred [ 0  2 10] [0.015 0.105 0.763]
# sym22. Pred [ 9  2 10] [0.015 0.277 0.597]
# sym23. Pred [ 9 10  2] [0.04  0.108 0.6  ]
# sym24. Pred [10  2  9] [0.094 0.156 0.526]
# sym25. Pred [ 0  9 10] [0.018 0.225 0.612]
# Tag id: 075594689104f56e31fa9423382c6954d8e0553b
# True text: 04604087002917 , Len: 14 , Pred text: 4604087002917 , Dist: 1
# Pred argmax ••••4•6•0•4008700••0299177
# sym0. Pred [ 4  0 10] [0.013 0.439 0.443]
# sym1. Pred [ 4  0 10] [0.01  0.45  0.466]
# sym2. Pred [ 4  0 10] [0.013 0.396 0.512]
# sym3. Pred [ 0  4 10] [0.014 0.442 0.458]
# sym4. Pred [ 6 10  4] [0.02  0.055 0.798]
# sym5. Pred [ 4  6 10] [0.313 0.313 0.315]
# sym6. Pred [ 4 10  6] [0.02  0.054 0.796]
# sym7. Pred [ 6  0 10] [0.313 0.313 0.315]
# sym8. Pred [ 4 10  0] [0.02  0.054 0.796]
# sym9. Pred [ 4  0 10] [0.313 0.313 0.315]
# sym10. Pred [ 0 10  4] [0.025 0.054 0.795]
# sym11. Pred [10  4  0] [0.057 0.122 0.684]
# sym12. Pred [10  8  0] [0.051 0.207 0.619]
# sym13. Pred [ 7 10  8] [0.038 0.062 0.749]
# sym14. Pred [ 8 10  7] [0.029 0.063 0.756]
# sym15. Pred [ 7 10  0] [0.306 0.317 0.317]
# sym16. Pred [ 7 10  0] [0.019 0.053 0.805]
# sym17. Pred [ 7  0 10] [0.016 0.053 0.808]
# sym18. Pred [ 2  0 10] [0.011 0.444 0.46 ]
# sym19. Pred [ 2 10  0] [0.023 0.064 0.765]
# sym20. Pred [ 0 10  2] [0.039 0.107 0.599]
# sym21. Pred [10  2  9] [0.088 0.332 0.411]
# sym22. Pred [ 1 10  9] [0.087 0.11  0.547]
# sym23. Pred [10  9  1] [0.097 0.125 0.543]
# sym24. Pred [ 1 10  7] [0.202 0.295 0.419]
# sym25. Pred [ 1 10  7] [0.028 0.061 0.732]
# Tag id: 195255c42d2067f1b1d32d4c18763e37b006e8ee
# True text: 54600697406794 , Len: 14 , Pred text: 4600697406794 , Dist: 1
# Pred argmax •••4•6•0••069774406•7•9•4•
# sym0. Pred [ 4  5 10] [0.014 0.431 0.449]
# sym1. Pred [ 4  5 10] [0.012 0.451 0.46 ]
# sym2. Pred [ 5  4 10] [0.24  0.347 0.347]
# sym3. Pred [ 5 10  4] [0.027 0.054 0.791]
# sym4. Pred [ 4  6 10] [0.313 0.313 0.315]
# sym5. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym6. Pred [ 6  0 10] [0.313 0.314 0.314]
# sym7. Pred [ 6 10  0] [0.019 0.053 0.805]
# sym8. Pred [ 6  0 10] [0.016 0.053 0.808]
# sym9. Pred [ 6  0 10] [0.011 0.444 0.459]
# sym10. Pred [10  6  0] [0.057 0.122 0.687]
# sym11. Pred [ 0 10  6] [0.023 0.063 0.761]
# sym12. Pred [ 6 10  9] [0.039 0.106 0.598]
# sym13. Pred [ 9 10  7] [0.192 0.205 0.504]
# sym14. Pred [10  4  7] [0.061 0.062 0.735]
# sym15. Pred [ 7 10  4] [0.02  0.055 0.792]
# sym16. Pred [10  0  4] [0.036 0.432 0.446]
# sym17. Pred [10  6  0] [0.058 0.117 0.684]
# sym18. Pred [ 0 10  6] [0.021 0.055 0.791]
# sym19. Pred [ 6  7 10] [0.313 0.314 0.314]
# sym20. Pred [ 6 10  7] [0.02  0.054 0.796]
# sym21. Pred [ 9  7 10] [0.175 0.376 0.378]
# sym22. Pred [ 7 10  9] [0.039 0.107 0.598]
# sym23. Pred [ 9  4 10] [0.144 0.39  0.392]
# sym24. Pred [ 7 10  4] [0.016 0.054 0.799]
# sym25. Pred [ 7  4 10] [0.013 0.44  0.442]
# Tag id: 401112a4a4ca77ed4e6cd583dc2472cb6a25b9dc
# True text: 0680275029120 , Len: 13 , Pred text: 680275029120 , Dist: 1
# Pred argmax •••6•8•0•2•7•5•0•2•9•1•2•0
# sym0. Pred [ 6  0 10] [0.023 0.048 0.751]
# sym1. Pred [ 6  0 10] [0.02  0.089 0.762]
# sym2. Pred [ 0  6 10] [0.058 0.43  0.431]
# sym3. Pred [ 0 10  6] [0.02  0.054 0.796]
# sym4. Pred [ 6  8 10] [0.313 0.313 0.315]
# sym5. Pred [ 0 10  8] [0.02  0.054 0.796]
# sym6. Pred [ 8  0 10] [0.313 0.313 0.315]
# sym7. Pred [ 8 10  0] [0.02  0.054 0.796]
# sym8. Pred [ 2  0 10] [0.175 0.376 0.378]
# sym9. Pred [ 0 10  2] [0.039 0.107 0.598]
# sym10. Pred [ 2  7 10] [0.144 0.39  0.392]
# sym11. Pred [ 5 10  7] [0.02  0.054 0.8  ]
# sym12. Pred [ 5  7 10] [0.313 0.313 0.315]
# sym13. Pred [ 0 10  5] [0.02  0.054 0.796]
# sym14. Pred [ 0  5 10] [0.313 0.313 0.315]
# sym15. Pred [ 5 10  0] [0.02  0.054 0.796]
# sym16. Pred [ 2  0 10] [0.176 0.376 0.378]
# sym17. Pred [ 9 10  2] [0.039 0.107 0.599]
# sym18. Pred [ 2  9 10] [0.182 0.23  0.495]
# sym19. Pred [ 2 10  9] [0.032 0.108 0.609]
# sym20. Pred [ 1  9 10] [0.191 0.191 0.52 ]
# sym21. Pred [ 2 10  1] [0.04  0.107 0.604]
# sym22. Pred [ 1  2 10] [0.22  0.22  0.473]
# sym23. Pred [ 1 10  2] [0.039 0.106 0.598]
# sym24. Pred [ 2  0 10] [0.146 0.382 0.396]
# sym25. Pred [ 1 10  0] [0.023 0.061 0.736]
# Tag id: 66e8e80edbe6f8b95a72844006871f26790dacec
# {13: (1359, 1394), 7: (425, 428), 6: (591, 599), 14: (70, 97), 9: (66, 66), 10: (33, 33), 8: (18, 20), 15: (4, 6), 16: (0, 2), 12: (4, 13), 11: (1, 1)}
# {13: 0.975, 7: 0.993, 6: 0.987, 14: 0.722, 9: 1.0, 10: 1.0, 8: 0.9, 15: 0.667, 16: 0.0, 12: 0.308, 11: 1.0}
# Mean: 0.05716 , Median: 0.0 , Min: 0 , Max: 13

# %%
# d = {14: (3, 79), 13: (1267, 1457), 7: (411, 432), 6: (561, 606), 9: (67, 67), 10: (32, 33), 15: (0, 5), 16: (0, 2), 12: (3, 16), 8: (20, 22)} # m7e80

# d = {14: (3, 79), 13: (1287, 1457), 7: (414, 432), 6: (559, 606), 9: (67, 67), 10: (33, 33), 15: (0, 5), 16: (0, 2), 12: (3, 16), 8: (20, 22)} # m8e103 test
# d = {14: (3, 79), 13: (1286, 1457), 7: (417, 432), 6: (560, 606), 9: (66, 67), 10: (33, 33), 15: (0, 5), 16: (0, 2), 12: (4, 16), 8: (20, 22)} # m8e165 test

# d = {7: (18452, 20092), 9: (9377, 9510), 6: (39518, 42663), 8: (1606, 1836), 10: (1543, 1775), 11: (58, 200), 13: (72288, 77363), 12: (859, 3415), 5: (382, 445), 14: (224, 923), 15: (338, 562), 16: (65, 126), 17: (2, 6)} # m8e103 train
# d = {14: (1, 79), 13: (1270, 1457), 7: (426, 432), 6: (594, 606), 9: (65, 67), 10: (33, 33), 15: (0, 5), 16: (0, 2), 12: (3, 16), 8: (19, 22)} # m16e32
# d = {14: (3, 79), 13: (1261, 1457), 7: (430, 432), 6: (593, 606), 9: (67, 67), 10: (33, 33), 15: (0, 5), 16: (0, 2), 12: (3, 16), 8: (19, 22)} # m22e54
# d = {14: (3, 79), 13: (1270, 1457), 7: (429, 432), 6: (599, 606), 9: (67, 67), 10: (33, 33), 15: (0, 5), 16: (0, 2), 12: (2, 16), 8: (19, 22)} # m37e16
# d = {13: (1359, 1394), 7: (425, 428), 6: (591, 599), 14: (70, 97), 9: (66, 66), 10: (33, 33), 8: (18, 20), 15: (4, 6), 16: (0, 2), 12: (4, 13), 11: (1, 1)} # m51e_best test_relabel_11_20
# d = {14: (47, 79), 13: (1382, 1457), 7: (428, 432), 6: (598, 606), 9: (67, 67), 10: (33, 33), 15: (3, 5), 16: (0, 2), 12: (2, 16), 8: (19, 22)} # m51e_best test_set_len26
d = {14: (42, 79), 13: (1383, 1457), 7: (431, 432), 6: (598, 606), 9: (67, 67), 10: (33, 33), 15: (2, 5), 16: (0, 2), 12: (1, 16), 8: (20, 22)} # m54e_best test_set_len26

# %%
total = 0
true = 0
for k, (t1, t2) in d.items():
    true += t1
    total += t2
print(true, total, total - true, true / total)
# Out:
# 2577 2719 142 0.9477749172489885

# %%
dataset_dir_path = '/srv/data_science/storage/product_code_ocr'
max_text_len = 26
w, h = 100, 32
n_classes = 10
df_name = f'test_set_len{max_text_len}'
# df_name = f'test_relabel_11_20_len{max_text_len}'
model_num = 51
epoch = find_best_model_epoch(model_num)
batch_size = 20
img_dir = f'images_train_padding_size{w}x{h}'
grcl_fsize = 3
# grcl_niter = 3
grcl_niter = 3
lstm_units = 512
accuracy_threshold = 98.5

# %%
metrics.test_metric_by_markets(dataset_dir_path, df_name, img_dir, model_num, epoch,
                               batch_size, max_text_len, h, w, n_classes,
                               grcl_niter, grcl_fsize, lstm_units, accuracy_threshold)
# Out:
# 100%|██████████| 2719/2719 [00:00<00:00, 4861.37it/s]
# {'5ka.ru': (100.0, 0.008263, 4.808), 'lenta.com': (98.598, 0.000185, 98.165), 'magnit-info.ru': (98.607, 7.9e-05, 99.538), 'billa.ru': (98.985, 0.0, 100.0), 'spar.ru': (99.038, 0.000106, 99.048), 'dixy.ru': (98.701, 0.0, 100.0), 'auchan.ru': (98.529, 0.000821, 88.312), 'okmarket.ru': (98.889, 0.000927, 86.957), 'globus.ru': (100.0, 0.0, 100.0), 'verno-info.ru': (100.0, 0.0, 100.0), 'maxi-retail.ru': (100.0, 0.0, 100.0)}
# {14: (47, 79), 13: (1382, 1457), 7: (428, 432), 6: (598, 606), 9: (67, 67), 10: (33, 33), 15: (3, 5), 16: (0, 2), 12: (2, 16), 8: (19, 22)}
# {14: 0.595, 13: 0.949, 7: 0.991, 6: 0.987, 9: 1.0, 10: 1.0, 15: 0.6, 16: 0.0, 12: 0.125, 8: 0.864}
# {'5ka.ru': (136, 208), 'lenta.com': (849, 872), 'magnit-info.ru': (637, 649), 'billa.ru': (390, 394), 'spar.ru': (103, 105), 'dixy.ru': (76, 77), 'auchan.ru': (69, 77), 'okmarket.ru': (189, 207), 'globus.ru': (45, 45), 'verno-info.ru': (68, 68), 'maxi-retail.ru': (17, 17)}
# {'5ka.ru': 0.654, 'lenta.com': 0.974, 'magnit-info.ru': 0.982, 'billa.ru': 0.99, 'spar.ru': 0.981, 'dixy.ru': 0.987, 'auchan.ru': 0.896, 'okmarket.ru': 0.913, 'globus.ru': 1.0, 'verno-info.ru': 1.0, 'maxi-retail.ru': 1.0}
# Mean: 0.08054 , Median: 0.0 , Min: 0 , Max: 10
# Mean: 0.00706 , Median: 0.00612 , Min: 0.0 , Max: 0.02646

# %%
test_d = {
    14: 0.038,
    13: 0.883,
    7: 0.958,
    6: 0.922,
    9: 1.0,
    10: 1.0,
    15: 0.0,
    16: 0.0,
    12: 0.188,
    8: 0.909,
}
train_d = {
    7: 0.918,
    9: 0.986,
    6: 0.926,
    8: 0.875,
    10: 0.869,
    11: 0.29,
    13: 0.934,
    12: 0.252,
    5: 0.858,
    14: 0.243,
    15: 0.601,
    16: 0.516,
    17: 0.333,
}


def print_metrics(test_d, train_d):
    for k in train_d.keys():
        if k in test_d:
            print(k, test_d[k], train_d[k])

# %%
dataset_dir_path = '/srv/data_science/storage/product_code_ocr'
df_name = 'test_set_google_bs_14'
metrics.test_google(dataset_dir_path, df_name)
# Out:
# {14: (51, 79), 13: (828, 1457), 7: (407, 432), 6: (495, 606), 9: (58, 67), 10: (31, 33), 15: (3, 5), 16: (2, 2), 12: (3, 16), 8: (13, 22)}
# {14: 0.646, 13: 0.568, 7: 0.942, 6: 0.817, 9: 0.866, 10: 0.939, 15: 0.6, 16: 1.0, 12: 0.188, 8: 0.591}
# Mean: 0.962118425891872 , Median: 0.0 , Min: 0 , Max: 22

# %%
d = {14: (51, 79), 13: (828, 1457), 7: (407, 432), 6: (495, 606), 9: (58, 67), 10: (31, 33), 15: (3, 5), 16: (2, 2), 12: (3, 16), 8: (13, 22)}

# %%
total = 0
true = 0
for k, (t1, t2) in d.items():
    true += t1
    total += t2
print(true, total, total - true, true / total)
# Out:
# 1891 2719 828 0.6954762780433983
