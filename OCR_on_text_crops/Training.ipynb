# %%
from grcnn import training
# Out:
# Using TensorFlow backend.

# %%
batch_size = 48
model_num = 46
initial_epoch = 0
width, height = 100, 32
# width, height = 128, 32
# width, height = 200, 32
max_text_len = 26
# max_text_len = 33
# max_text_len = 51
# n_classes = 11
n_classes = 10
epochs = 400
# grcl_niter = 5
grcl_niter = 3
grcl_fsize = 3
lstm_units = 512
train_augment_prob = .5
# img_dir = f'cropped_images_train_size{width}x{height}'
img_dir = f'images_train_padding_size{width}x{height}'
train_df_name = f'train_set_len{max_text_len}_filtered'
val_df_name = f'val_set_len{max_text_len}_filtered'
# val_df_name = f'val_relabel_11_20_len{max_text_len}'
# train_df_name = f'train_relabel_11_20_len{max_text_len}'

# %%
training.train(train_df_name, val_df_name, img_dir, model_num, initial_epoch, epochs, train_augment_prob, batch_size,
          width, height, max_text_len, n_classes, grcl_niter, grcl_fsize, lstm_units)
# Out:
# Epoch 1/400
# 3311/3311 [==============================] - 279s 84ms/step - loss: 10.1119 - ctc_loss: 10.1119 - val_loss: 6.9017 - val_ctc_loss: 6.9017
# Epoch 2/400
# 3311/3311 [==============================] - 277s 84ms/step - loss: 6.9806 - ctc_loss: 6.9806 - val_loss: 6.4104 - val_ctc_loss: 6.4104
# Epoch 3/400
# 3311/3311 [==============================] - 278s 84ms/step - loss: 6.6439 - ctc_loss: 6.6439 - val_loss: 6.3513 - val_ctc_loss: 6.3513
# Epoch 4/400
# 3311/3311 [==============================] - 278s 84ms/step - loss: 6.4968 - ctc_loss: 6.4968 - val_loss: 6.2287 - val_ctc_loss: 6.2287
# Epoch 5/400
# 3311/3311 [==============================] - 278s 84ms/step - loss: 6.3977 - ctc_loss: 6.3977 - val_loss: 6.1482 - val_ctc_loss: 6.1482
# Epoch 6/400
# 3311/3311 [==============================] - 278s 84ms/step - loss: 6.3428 - ctc_loss: 6.3428 - val_loss: 6.1549 - val_ctc_loss: 6.1549
# Epoch 7/400
# ...
